# %%
import re
import urllib.request
import bs4 as BeautifulSoup
import nltk
import heapq
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\efecank\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\efecank\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
stop_words = stopwords.words('english')

# %%
scraped_data = urllib.request.urlopen('https://en.wikipedia.org/wiki/Automatic_summarization')

# %%
article = scraped_data.read()

# %%
article_parsed = BeautifulSoup.BeautifulSoup(article,'lxml')

# %%
paragraphs = article_parsed.find_all('p')

# %%
article_content = ''
for p in paragraphs:
    article_content += p.text

# %%
article_content = re.sub(r'\[[0-9]*\]', ' ', article_content)
article_content = re.sub(r'\s+', ' ', article_content)

# %%
formatted_article_content = re.sub('[^a-zA-Z]', ' ', article_content )
formatted_article_content = re.sub(r'\s+', ' ', formatted_article_content)

# %%
words = word_tokenize(formatted_article_content)

# %%
word_frequencies = {}

for word in words:
    word = word.lower()
    if word not in stop_words:
        if word not in word_frequencies.keys():
            word_frequencies[word] = 1
        else:
            word_frequencies[word] += 1

# %%
word_frequencies
# Out:
# {'automatic': 14,
#  'summarization': 76,
#  'process': 7,
#  'shortening': 1,
#  'set': 19,
#  'data': 7,
#  'computationally': 2,
#  'create': 8,
#  'subset': 3,
#  'summary': 28,
#  'represents': 2,
#  'important': 13,
#  'relevant': 5,
#  'information': 16,
#  'within': 3,
#  'original': 15,
#  'content': 13,
#  'artificial': 1,
#  'intelligence': 1,
#  'algorithms': 12,
#  'commonly': 1,
#  'developed': 4,
#  'employed': 2,
#  'achieve': 3,
#  'specialized': 1,
#  'different': 10,
#  'types': 2,
#  'text': 50,
#  'usually': 2,
#  'implemented': 1,
#  'natural': 6,
#  'language': 6,
#  'processing': 7,
#  'methods': 13,
#  'designed': 2,
#  'locate': 1,
#  'informative': 2,
#  'sentences': 31,
#  'given': 8,
#  'document': 40,
#  'hand': 2,
#  'visual': 2,
#  'summarized': 1,
#  'using': 16,
#  'computer': 2,
#  'vision': 1,
#  'image': 7,
#  'subject': 1,
#  'ongoing': 1,
#  'research': 5,
#  'existing': 4,
#  'approaches': 6,
#  'typically': 5,
#  'attempt': 1,
#  'display': 1,
#  'representative': 4,
#  'images': 8,
#  'collection': 7,
#  'generate': 4,
#  'video': 12,
#  'includes': 2,
#  'entire': 3,
#  'identify': 4,
#  'extract': 4,
#  'frames': 5,
#  'key': 8,
#  'segments': 3,
#  'shots': 1,
#  'normally': 1,
#  'temporally': 1,
#  'ordered': 1,
#  'fashion': 1,
#  'summaries': 25,
#  'simply': 5,
#  'retain': 1,
#  'carefully': 1,
#  'selected': 3,
#  'therefore': 1,
#  'identical': 2,
#  'output': 5,
#  'synopsis': 1,
#  'new': 6,
#  'synthesized': 1,
#  'based': 21,
#  'google': 2,
#  'docs': 1,
#  'released': 1,
#  'feature': 2,
#  'two': 10,
#  'general': 4,
#  'extraction': 20,
#  'abstraction': 3,
#  'extracted': 5,
#  'modified': 1,
#  'way': 13,
#  'examples': 11,
#  'include': 6,
#  'phrases': 6,
#  'used': 18,
#  'tag': 1,
#  'index': 2,
#  'including': 2,
#  'headings': 2,
#  'collectively': 1,
#  'comprise': 1,
#  'abstract': 3,
#  'stated': 1,
#  'analogous': 1,
#  'skimming': 1,
#  'available': 2,
#  'subheadings': 1,
#  'figures': 1,
#  'first': 9,
#  'last': 2,
#  'paragraphs': 1,
#  'section': 1,
#  'optionally': 1,
#  'paragraph': 1,
#  'read': 3,
#  'one': 15,
#  'chooses': 1,
#  'detail': 1,
#  'sequences': 4,
#  'terms': 4,
#  'clinical': 1,
#  'relevance': 7,
#  'patient': 1,
#  'problem': 11,
#  'intervention': 2,
#  'outcome': 1,
#  'abstractive': 4,
#  'exist': 1,
#  'applied': 6,
#  'mainly': 2,
#  'build': 2,
#  'internal': 1,
#  'semantic': 4,
#  'representation': 3,
#  'often': 6,
#  'called': 6,
#  'model': 10,
#  'use': 7,
#  'closer': 1,
#  'human': 14,
#  'might': 11,
#  'express': 1,
#  'may': 4,
#  'transform': 1,
#  'paraphrasing': 2,
#  'sections': 1,
#  'source': 5,
#  'condense': 1,
#  'strongly': 1,
#  'transformation': 1,
#  'however': 5,
#  'much': 3,
#  'challenging': 1,
#  'involving': 1,
#  'deep': 2,
#  'understanding': 3,
#  'domain': 14,
#  'cases': 2,
#  'relates': 1,
#  'special': 5,
#  'field': 2,
#  'knowledge': 4,
#  'even': 1,
#  'difficult': 4,
#  'apply': 4,
#  'videos': 4,
#  'systems': 8,
#  'extractive': 6,
#  'aimed': 2,
#  'higher': 1,
#  'quality': 1,
#  'rely': 2,
#  'combined': 6,
#  'software': 3,
#  'effort': 2,
#  'machine': 8,
#  'aided': 2,
#  'techniques': 4,
#  'highlight': 1,
#  'candidate': 1,
#  'passages': 1,
#  'inclusion': 3,
#  'adds': 2,
#  'removes': 2,
#  'post': 4,
#  'processes': 2,
#  'edits': 1,
#  'translation': 2,
#  'translate': 1,
#  'broadly': 1,
#  'tasks': 3,
#  'depending': 3,
#  'program': 1,
#  'focuses': 4,
#  'generic': 3,
#  'obtaining': 1,
#  'whether': 1,
#  'documents': 14,
#  'sets': 2,
#  'news': 11,
#  'stories': 1,
#  'etc': 6,
#  'second': 2,
#  'query': 6,
#  'sometimes': 2,
#  'summarizes': 1,
#  'objects': 3,
#  'specific': 7,
#  'able': 4,
#  'generated': 4,
#  'user': 6,
#  'needs': 1,
#  'example': 21,
#  'attempts': 2,
#  'automatically': 6,
#  'produce': 10,
#  'interested': 1,
#  'generating': 4,
#  'single': 4,
#  'others': 4,
#  'multiple': 6,
#  'cluster': 2,
#  'articles': 6,
#  'topic': 5,
#  'multi': 15,
#  'related': 5,
#  'application': 3,
#  'summarizing': 4,
#  'imagine': 2,
#  'system': 15,
#  'pulls': 1,
#  'together': 4,
#  'web': 3,
#  'concisely': 1,
#  'latest': 1,
#  'another': 6,
#  'consists': 1,
#  'selecting': 2,
#  'larger': 4,
#  'context': 1,
#  'useful': 3,
#  'show': 4,
#  'results': 9,
#  'exploration': 1,
#  'creates': 2,
#  'trailer': 1,
#  'long': 2,
#  'also': 20,
#  'applications': 4,
#  'consumer': 1,
#  'personal': 1,
#  'want': 4,
#  'skip': 1,
#  'boring': 2,
#  'repetitive': 1,
#  'actions': 1,
#  'similarly': 7,
#  'surveillance': 1,
#  'would': 13,
#  'suspicious': 1,
#  'activity': 1,
#  'ignoring': 1,
#  'redundant': 1,
#  'captured': 1,
#  'high': 6,
#  'level': 2,
#  'try': 1,
#  'find': 3,
#  'subsets': 1,
#  'like': 9,
#  'cover': 7,
#  'core': 1,
#  'notions': 2,
#  'diversity': 8,
#  'coverage': 6,
#  'representativeness': 1,
#  'additionally': 1,
#  'naturally': 3,
#  'problems': 7,
#  'textrank': 15,
#  'pagerank': 8,
#  'submodular': 25,
#  'function': 9,
#  'determinantal': 3,
#  'point': 3,
#  'maximal': 2,
#  'marginal': 3,
#  'mmr': 2,
#  'task': 6,
#  'following': 4,
#  'piece': 2,
#  'journal': 2,
#  'article': 3,
#  'must': 3,
#  'list': 2,
#  'keywords': 2,
#  'phrase': 4,
#  'capture': 1,
#  'primary': 1,
#  'topics': 2,
#  'discussed': 3,
#  'case': 9,
#  'many': 15,
#  'authors': 3,
#  'provide': 2,
#  'manually': 2,
#  'assigned': 2,
#  'lacks': 1,
#  'pre': 1,
#  'keyphrases': 31,
#  'rarely': 1,
#  'attached': 1,
#  'number': 9,
#  'consider': 1,
#  'keyphrase': 19,
#  'extractor': 2,
#  'select': 3,
#  'army': 1,
#  'corps': 1,
#  'engineers': 1,
#  'president': 1,
#  'bush': 1,
#  'orleans': 1,
#  'defective': 1,
#  'flood': 1,
#  'control': 1,
#  'pumps': 1,
#  'pulled': 1,
#  'directly': 2,
#  'contrast': 1,
#  'somehow': 1,
#  'internalize': 1,
#  'appear': 8,
#  'closely': 1,
#  'resemble': 1,
#  'political': 1,
#  'negligence': 1,
#  'inadequate': 1,
#  'protection': 1,
#  'floods': 1,
#  'requires': 2,
#  'makes': 2,
#  'enable': 1,
#  'browsing': 1,
#  'providing': 1,
#  'short': 2,
#  'improve': 1,
#  'retrieval': 1,
#  'could': 6,
#  'search': 3,
#  'reliable': 1,
#  'hits': 1,
#  'full': 1,
#  'entries': 1,
#  'large': 5,
#  'corpus': 2,
#  'literature': 1,
#  'definition': 1,
#  'words': 9,
#  'keyword': 1,
#  'highly': 5,
#  'theme': 1,
#  'beginning': 1,
#  'work': 5,
#  'turney': 7,
#  'researchers': 2,
#  'approached': 1,
#  'supervised': 16,
#  'learning': 12,
#  'construct': 1,
#  'unigram': 4,
#  'bigram': 3,
#  'trigram': 3,
#  'found': 4,
#  'though': 3,
#  'units': 3,
#  'possible': 2,
#  'compute': 1,
#  'various': 4,
#  'features': 16,
#  'describing': 1,
#  'e': 8,
#  'g': 3,
#  'begin': 1,
#  'upper': 1,
#  'letter': 1,
#  'assume': 1,
#  'known': 10,
#  'training': 12,
#  'assign': 3,
#  'positive': 2,
#  'negative': 3,
#  'labels': 2,
#  'learn': 7,
#  'classifier': 5,
#  'discriminate': 2,
#  'classifiers': 2,
#  'make': 2,
#  'binary': 3,
#  'classification': 7,
#  'test': 4,
#  'probability': 2,
#  'instance': 3,
#  'rule': 2,
#  'says': 1,
#  'initial': 1,
#  'capital': 1,
#  'letters': 1,
#  'likely': 5,
#  'learner': 2,
#  'manner': 1,
#  'generation': 1,
#  'strategy': 1,
#  'run': 2,
#  'determine': 3,
#  'looking': 1,
#  'decisions': 1,
#  'probabilities': 4,
#  'returned': 1,
#  'learned': 1,
#  'threshold': 4,
#  'extractors': 1,
#  'generally': 1,
#  'evaluated': 1,
#  'precision': 3,
#  'recall': 8,
#  'measures': 4,
#  'proposed': 3,
#  'actually': 1,
#  'correct': 1,
#  'true': 1,
#  'f': 2,
#  'score': 4,
#  'harmonic': 1,
#  'mean': 2,
#  'pr': 1,
#  'p': 1,
#  'r': 1,
#  'matches': 1,
#  'checked': 1,
#  'stemming': 1,
#  'applying': 5,
#  'normalization': 1,
#  'designing': 1,
#  'involves': 2,
#  'deciding': 1,
#  'several': 5,
#  'choices': 1,
#  'unsupervised': 6,
#  'choice': 1,
#  'exactly': 2,
#  'unigrams': 13,
#  'bigrams': 2,
#  'trigrams': 2,
#  'without': 2,
#  'intervening': 1,
#  'punctuation': 1,
#  'removing': 1,
#  'stopwords': 1,
#  'hulth': 3,
#  'showed': 1,
#  'get': 3,
#  'improvement': 1,
#  'tokens': 1,
#  'match': 2,
#  'certain': 2,
#  'patterns': 1,
#  'part': 3,
#  'speech': 2,
#  'tags': 1,
#  'ideally': 2,
#  'mechanism': 1,
#  'produces': 1,
#  'labeled': 2,
#  'candidates': 2,
#  'never': 1,
#  'containing': 1,
#  'four': 3,
#  'thus': 9,
#  'suffer': 1,
#  'lead': 1,
#  'low': 1,
#  'need': 8,
#  'describe': 1,
#  'enough': 1,
#  'allow': 1,
#  'algorithm': 17,
#  'non': 2,
#  'involve': 1,
#  'term': 2,
#  'frequencies': 1,
#  'times': 2,
#  'appears': 3,
#  'current': 1,
#  'length': 5,
#  'relative': 1,
#  'position': 5,
#  'occurrence': 4,
#  'boolean': 1,
#  'syntactic': 1,
#  'contains': 2,
#  'caps': 1,
#  'paper': 3,
#  'uses': 6,
#  'reduced': 1,
#  'successful': 1,
#  'kea': 1,
#  'derived': 1,
#  'seminal': 1,
#  'end': 3,
#  'return': 1,
#  'limit': 2,
#  'ensemble': 1,
#  'votes': 1,
#  'numeric': 1,
#  'scores': 3,
#  'thresholded': 1,
#  'provided': 2,
#  'technique': 3,
#  'c': 1,
#  'decision': 2,
#  'trees': 2,
#  'implicitly': 1,
#  'determines': 1,
#  'appropriate': 1,
#  'created': 4,
#  'predict': 1,
#  'virtually': 1,
#  'naive': 2,
#  'bayes': 2,
#  'induction': 1,
#  'genex': 1,
#  'genetic': 2,
#  'parameters': 3,
#  'follows': 1,
#  'series': 1,
#  'heuristics': 2,
#  'optimizes': 1,
#  'respect': 2,
#  'performance': 2,
#  'nice': 2,
#  'properties': 2,
#  'interpretable': 1,
#  'rules': 1,
#  'characterize': 2,
#  'require': 2,
#  'amount': 1,
#  'needed': 3,
#  'furthermore': 2,
#  'tends': 1,
#  'customize': 1,
#  'resulting': 4,
#  'necessarily': 2,
#  'portable': 3,
#  'demonstrate': 1,
#  'angle': 1,
#  'instead': 2,
#  'trying': 1,
#  'explicit': 1,
#  'exploits': 1,
#  'structure': 1,
#  'central': 3,
#  'selects': 1,
#  'pages': 2,
#  'notion': 2,
#  'prestige': 1,
#  'recommendation': 2,
#  'social': 1,
#  'networks': 1,
#  'previous': 1,
#  'rather': 1,
#  'arbitrary': 3,
#  'intrinsic': 4,
#  'easily': 3,
#  'domains': 1,
#  'languages': 1,
#  'purpose': 2,
#  'graph': 15,
#  'ranking': 7,
#  'nlp': 4,
#  'essentially': 2,
#  'runs': 1,
#  'specially': 1,
#  'particular': 1,
#  'builds': 1,
#  'vertices': 8,
#  'edges': 7,
#  'measure': 3,
#  'lexical': 1,
#  'similarity': 9,
#  'unit': 1,
#  'unlike': 2,
#  'undirected': 1,
#  'weighted': 1,
#  'reflect': 1,
#  'degree': 3,
#  'constructed': 2,
#  'form': 3,
#  'stochastic': 1,
#  'matrix': 2,
#  'damping': 1,
#  'factor': 2,
#  'random': 6,
#  'surfer': 1,
#  'obtained': 2,
#  'finding': 2,
#  'eigenvector': 2,
#  'corresponding': 2,
#  'eigenvalue': 1,
#  'stationary': 4,
#  'distribution': 2,
#  'walk': 4,
#  'correspond': 1,
#  'rank': 6,
#  'potentially': 2,
#  'something': 1,
#  'similar': 11,
#  'vertex': 3,
#  'keep': 1,
#  'small': 1,
#  'decide': 1,
#  'individual': 3,
#  'step': 7,
#  'merges': 1,
#  'ranked': 5,
#  'adjacent': 2,
#  'word': 5,
#  'side': 1,
#  'effect': 1,
#  'allowing': 1,
#  'us': 1,
#  'advanced': 1,
#  'ranks': 2,
#  'look': 1,
#  'see': 1,
#  'consecutively': 1,
#  'final': 3,
#  'note': 2,
#  'placed': 2,
#  'filtered': 1,
#  'adjectives': 1,
#  'nouns': 1,
#  'best': 2,
#  'linguistic': 1,
#  'comes': 1,
#  'play': 1,
#  'co': 5,
#  'connected': 3,
#  'edge': 2,
#  'window': 1,
#  'size': 2,
#  'n': 5,
#  'around': 2,
#  'linked': 2,
#  'string': 1,
#  'cohesion': 1,
#  'idea': 3,
#  'near': 1,
#  'meaningful': 1,
#  'recommend': 2,
#  'reader': 2,
#  'since': 3,
#  'method': 5,
#  'limited': 1,
#  'chosen': 1,
#  'count': 1,
#  'specified': 2,
#  'fraction': 2,
#  'total': 1,
#  'top': 3,
#  'merge': 1,
#  'instances': 3,
#  'result': 3,
#  'less': 1,
#  'produced': 1,
#  'roughly': 1,
#  'proportional': 1,
#  'initially': 1,
#  'clear': 1,
#  'think': 1,
#  'throughout': 1,
#  'occurring': 1,
#  'neighbors': 2,
#  'occur': 2,
#  'un': 1,
#  'semi': 1,
#  'hub': 1,
#  'connects': 1,
#  'modifying': 1,
#  'running': 1,
#  'places': 1,
#  'importance': 6,
#  'contribute': 1,
#  'ends': 1,
#  'along': 1,
#  'probably': 2,
#  'contain': 3,
#  'densely': 2,
#  'regions': 1,
#  'contexts': 1,
#  'assigns': 1,
#  'centers': 1,
#  'clusters': 1,
#  'getting': 1,
#  'approach': 5,
#  'considered': 3,
#  'aims': 1,
#  'essence': 1,
#  'real': 2,
#  'difference': 1,
#  'dealing': 1,
#  'whole': 1,
#  'basically': 1,
#  'good': 3,
#  'sentence': 13,
#  'main': 3,
#  'difficulty': 1,
#  'extracting': 1,
#  'people': 1,
#  'abstracts': 1,
#  'sufficient': 1,
#  'still': 3,
#  'evaluation': 13,
#  'purposes': 1,
#  'rouge': 7,
#  'considers': 2,
#  'duc': 7,
#  'workshops': 1,
#  'tno': 1,
#  'hybrid': 1,
#  'statistical': 2,
#  'models': 9,
#  'modeling': 2,
#  'salience': 1,
#  'although': 2,
#  'exhibited': 1,
#  'wanted': 1,
#  'explore': 1,
#  'effectiveness': 1,
#  'maximum': 3,
#  'entropy': 2,
#  'meeting': 1,
#  'robust': 1,
#  'dependencies': 1,
#  'successfully': 2,
#  'broadcast': 1,
#  'promising': 1,
#  'adaptive': 1,
#  'recognizing': 1,
#  'genre': 2,
#  'optimized': 1,
#  'quite': 1,
#  'spirit': 1,
#  'gets': 1,
#  'issue': 2,
#  'costly': 1,
#  'centroid': 2,
#  'vector': 1,
#  'regard': 2,
#  'principled': 1,
#  'estimate': 1,
#  'walks': 2,
#  'centrality': 2,
#  'lexrank': 9,
#  'groups': 1,
#  'time': 4,
#  'focused': 1,
#  'creating': 2,
#  'overlap': 2,
#  'cosine': 2,
#  'tf': 1,
#  'idf': 1,
#  'vectors': 1,
#  'common': 4,
#  'normalized': 1,
#  'lengths': 1,
#  'explored': 1,
#  'unweighted': 1,
#  'values': 1,
#  'experimented': 1,
#  'weights': 3,
#  'equal': 1,
#  'continuous': 1,
#  'formed': 1,
#  'combining': 1,
#  'cutoff': 1,
#  'worth': 1,
#  'noting': 1,
#  'described': 2,
#  'mead': 1,
#  'combines': 1,
#  'linear': 1,
#  'combination': 1,
#  'either': 1,
#  'tuned': 1,
#  'additional': 1,
#  'absolutely': 1,
#  'necessary': 1,
#  'procedure': 2,
#  'texts': 3,
#  'written': 2,
#  'report': 1,
#  'allows': 2,
#  'users': 1,
#  'professional': 1,
#  'consumers': 1,
#  'quickly': 1,
#  'familiarize': 1,
#  'contained': 1,
#  'complementing': 1,
#  'aggregators': 1,
#  'performing': 1,
#  'next': 1,
#  'road': 1,
#  'coping': 1,
#  'overload': 1,
#  'done': 1,
#  'response': 1,
#  'question': 1,
#  'reports': 1,
#  'concise': 1,
#  'comprehensive': 2,
#  'opinions': 1,
#  'put': 1,
#  'outlined': 1,
#  'every': 1,
#  'perspectives': 1,
#  'goal': 1,
#  'brief': 1,
#  'simplify': 1,
#  'cut': 1,
#  'pointing': 1,
#  'required': 2,
#  'hence': 2,
#  'limiting': 1,
#  'accessing': 1,
#  'files': 1,
#  'refinement': 1,
#  'present': 1,
#  'sources': 1,
#  'algorithmically': 1,
#  'editorial': 1,
#  'touch': 1,
#  'subjective': 1,
#  'making': 1,
#  'completely': 1,
#  'unbiased': 1,
#  'dubious': 1,
#  'discuss': 1,
#  'faces': 1,
#  'redundancy': 2,
#  'ideas': 1,
#  'diverse': 1,
#  'differ': 1,
#  'event': 1,
#  'address': 1,
#  'applies': 2,
#  'heuristic': 1,
#  'order': 2,
#  'discards': 1,
#  'ones': 1,
#  'already': 1,
#  'cross': 1,
#  'subsumption': 1,
#  'csis': 1,
#  'great': 1,
#  'stems': 1,
#  'recommending': 1,
#  'turn': 1,
#  'intuitive': 1,
#  'sense': 1,
#  'independent': 2,
#  'indicating': 1,
#  'vary': 1,
#  'considerably': 1,
#  'biomedical': 1,
#  'page': 1,
#  'lex': 1,
#  'handles': 1,
#  'unified': 1,
#  'mathematical': 1,
#  'framework': 1,
#  'absorbing': 1,
#  'markov': 1,
#  'chain': 1,
#  'states': 1,
#  'grasshopper': 2,
#  'addition': 1,
#  'explicitly': 1,
#  'promoting': 1,
#  'incorporates': 1,
#  'prior': 1,
#  'state': 4,
#  'art': 4,
#  'mixtures': 2,
#  'functions': 14,
#  'achieved': 3,
#  'corpora': 2,
#  'lingual': 1,
#  'avoids': 1,
#  'generates': 1,
#  'ideograms': 1,
#  'represent': 1,
#  'meaning': 1,
#  'evaluates': 2,
#  'comparing': 1,
#  'ideogram': 1,
#  'shape': 1,
#  'frequency': 3,
#  'preprocessing': 1,
#  'supplied': 1,
#  'equivalence': 1,
#  'equivalent': 1,
#  'desired': 1,
#  'recently': 2,
#  'emerged': 1,
#  'powerful': 2,
#  'tool': 1,
#  'moreover': 4,
#  'combinatorial': 1,
#  'optimization': 6,
#  'concepts': 3,
#  'facility': 2,
#  'location': 2,
#  'seen': 1,
#  'encouraging': 1,
#  'efficiently': 1,
#  'combine': 1,
#  'supervision': 1,
#  'right': 2,
#  'fitting': 1,
#  'admit': 1,
#  'efficient': 1,
#  'simple': 2,
#  'greedy': 2,
#  'admits': 1,
#  'constant': 1,
#  'guarantee': 1,
#  'extremely': 1,
#  'implement': 1,
#  'scale': 1,
#  'datasets': 2,
#  'almost': 1,
#  'lin': 2,
#  'bilmes': 2,
#  'shows': 2,
#  'date': 1,
#  'breakthrough': 1,
#  'establishing': 1,
#  'citation': 1,
#  'tschiatschek': 2,
#  'et': 3,
#  'al': 3,
#  'bairi': 1,
#  'utility': 1,
#  'hierarchies': 1,
#  'evaluate': 2,
#  'informativeness': 2,
#  'compare': 2,
#  'made': 2,
#  'extrinsic': 3,
#  'inter': 2,
#  'textual': 4,
#  'intra': 2,
#  'assesses': 1,
#  'affects': 1,
#  'completion': 1,
#  'evaluations': 2,
#  'assessed': 1,
#  'coherence': 2,
#  'tested': 1,
#  'impact': 1,
#  'assessment': 1,
#  'reading': 1,
#  'comprehension': 1,
#  'assess': 1,
#  'contrastive': 1,
#  'analysis': 2,
#  'outputs': 1,
#  'judgement': 1,
#  'varies': 1,
#  'greatly': 1,
#  'particularly': 1,
#  'manual': 2,
#  'labor': 1,
#  'intensive': 1,
#  'humans': 1,
#  'issues': 1,
#  'concerning': 1,
#  'oriented': 1,
#  'understudy': 1,
#  'gisting': 1,
#  'nist': 1,
#  'conferences': 1,
#  'well': 2,
#  'covers': 1,
#  ...}

# %%
maximum_frequency = max(word_frequencies.values())

for word in word_frequencies.keys():
    word_frequencies[word] = (word_frequencies[word]/maximum_frequency)

# %%
maximum_frequency
# Out:
# 76

# %%
sentence_list = sent_tokenize(article_content)

# %%
sentence_scores = {}

for sent in sentence_list:
    for word, frequency in word_frequencies.items():
        if word in sent.lower():
            if sent not in sentence_scores.keys():
                sentence_scores[sent] = frequency
            else:
                sentence_scores[sent] += frequency

# %%
sentence_scores
# Out:
# {'Automatic summarization is the process of shortening a set of data computationally, to create a subset (a summary) that represents the most important or relevant information within the original content.': 3.6052631578947345,
#  'Artificial intelligence algorithms are commonly developed and employed to achieve this, specialized for different types of data.': 1.3815789473684208,
#  'Text summarization is usually implemented by natural language processing methods, designed to locate the most informative sentences in a given document.': 3.986842105263156,
#  'On the other hand, visual content can be summarized using computer vision algorithms.': 1.263157894736842,
#  'Image summarization is the subject of ongoing research; existing approaches typically attempt to display the most representative images from a given image collection, or generate a video that only includes the most important content from the entire collection.': 3.0263157894736823,
#  'Video summarization algorithms identify and extract from the original video content the most important frames (key-frames), and/or the most important video segments (key-shots), normally in a temporally ordered fashion.': 2.8684210526315774,
#  'Video summaries simply retain a carefully selected subset of the original video frames and, therefore, are not identical to the output of video synopsis algorithms, where new video frames are being synthesized based on the original video content.': 2.723684210526315,
#  'In 2022 Google Docs released an automatic summarization feature.': 1.526315789473684,
#  'There are two general approaches to automatic summarization: extraction and abstraction.': 2.2105263157894735,
#  'Here, content is extracted from the original data, but the extracted content is not modified in any way.': 1.1315789473684212,
#  'Examples of extracted content include key-phrases that can be used to "tag" or index a text document, or key sentences (including headings) that collectively comprise an abstract, and representative images or video segments, as stated above.': 4.2105263157894735,
#  'For text, extraction is analogous to the process of skimming, where the summary (if available), headings and subheadings, figures, the first and last paragraphs of a section, and optionally the first and last sentences in a paragraph are read before one chooses to read the entire document in detail.': 3.7894736842105234,
#  'Other examples of extraction that include key sequences of text in terms of clinical relevance (including patient/problem, intervention, and outcome).': 2.4868421052631566,
#  'Abstractive summarization methods generate new text that did not exist in the original text.': 2.657894736842105,
#  'This has been applied mainly for text.': 1.0263157894736843,
#  'Abstractive methods build an internal semantic representation of the original content (often called a language model), and then use this representation to create a summary that is closer to what a human might express.': 2.6447368421052615,
#  'Abstraction may transform the extracted content by paraphrasing sections of the source document, to condense a text more strongly than extraction.': 2.4078947368421044,
#  'Such transformation, however, is computationally much more challenging than extraction, involving both natural language processing and often a deep understanding of the domain of the original text in cases where the original document relates to a special field of knowledge.': 3.3815789473684186,
#  '"Paraphrasing" is even more difficult to apply to images and videos, which is why most summarization systems are extractive.': 2.2894736842105257,
#  'Approaches aimed at higher summarization quality rely on combined software and human effort.': 2.039473684210526,
#  'In Machine Aided Human Summarization, extractive techniques highlight candidate passages for inclusion (to which the human adds or removes text).': 2.723684210526314,
#  'In Human Aided Machine Summarization, a human post-processes software output, in the same way that one edits the output of automatic translation by Google Translate.': 2.526315789473683,
#  'There are broadly two types of extractive summarization tasks depending on what the summarization program focuses on.': 2.118421052631578,
#  'The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.).': 3.9999999999999987,
#  'The second is query relevant summarization, sometimes called query-based summarization, which summarizes objects specific to a query.': 2.1578947368421053,
#  'Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs.': 3.486842105263156,
#  'An example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document.': 2.94736842105263,
#  'Sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic).': 3.0657894736842093,
#  'This problem is called multi-document summarization.': 2.2105263157894735,
#  'A related application is summarizing news articles.': 0.8026315789473686,
#  'Imagine a system, which automatically pulls together news articles on a given topic (from the web), and concisely represents the latest news as a summary.': 2.1973684210526305,
#  'Image collection summarization is another application example of automatic summarization.': 2.1052631578947367,
#  'It consists in selecting a representative set of images from a larger set of images.': 1.1315789473684212,
#  'A summary in this context is useful to show the most representative images of results in an image collection exploration system.': 2.3421052631578934,
#  'Video summarization is a related domain, where the system automatically creates a trailer of a long video.': 2.38157894736842,
#  'This also has applications in consumer or personal videos, where one might want to skip the boring or repetitive actions.': 1.4473684210526312,
#  'Similarly, in surveillance videos, one would want to extract important and suspicious activity, while ignoring all the boring and redundant frames captured.': 1.6184210526315785,
#  'At a very high level, summarization algorithms try to find subsets of objects (like set of sentences, or a set of images), which cover information of the entire set.': 3.5921052631578925,
#  'This is also called the core-set.': 0.8815789473684211,
#  'These algorithms model notions like diversity, coverage, information and representativeness of the summary.': 2.0789473684210518,
#  'Query based summarization techniques, additionally model for relevance of the summary with the query.': 2.342105263157894,
#  'Some techniques and algorithms which naturally model summarization problems are TextRank and PageRank, Submodular set function, Determinantal point process, maximal marginal relevance (MMR) etc.': 4.552631578947368,
#  'The task is the following.': 0.38157894736842096,
#  'You are given a piece of text, such as a journal article, and you must produce a list of keywords or key[phrase]s that capture the primary topics discussed in the text.': 2.1447368421052633,
#  'In the case of research articles, many authors provide manually assigned keywords, but most text lacks pre-existing keyphrases.': 2.9736842105263146,
#  'For example, news articles rarely have keyphrases attached, but it would be useful to be able to automatically do so for a number of applications discussed below.': 2.8157894736842093,
#  'Consider the example text from a news article: A keyphrase extractor might select "Army Corps of Engineers", "President Bush", "New Orleans", and "defective flood-control pumps" as keyphrases.': 2.9473684210526296,
#  'These are pulled directly from the text.': 0.8684210526315791,
#  'In contrast, an abstractive keyphrase system would somehow internalize the content and generate keyphrases that do not appear in the text, but more closely resemble what a human might produce, such as "political negligence" or "inadequate protection from floods".': 3.4868421052631557,
#  'Abstraction requires a deep understanding of the text, which makes it difficult for a computer system.': 1.5657894736842106,
#  'Keyphrases have many applications.': 1.3947368421052628,
#  'They can enable document browsing by providing a short summary, improve information retrieval (if documents have keyphrases assigned, a user could search by keyphrase to produce more reliable hits than a full-text search), and be employed in generating index entries for a large text corpus.': 4.302631578947367,
#  'Depending on the different literature and the definition of key terms, words or phrases, keyword extraction is a highly related theme.': 1.5789473684210527,
#  'Beginning with the work of Turney, many researchers have approached keyphrase extraction as a supervised machine learning problem.': 2.328947368421052,
#  'Given a document, we construct an example for each unigram, bigram, and trigram found in the text (though other text units are also possible, as discussed below).': 2.6710526315789456,
#  'We then compute various features describing each example (e.g., does the phrase begin with an upper-case letter?).': 1.210526315789474,
#  'We assume there are known keyphrases available for a set of training documents.': 2.5526315789473677,
#  'Using the known keyphrases, we can assign positive or negative labels to the examples.': 2.0526315789473686,
#  'Then we learn a classifier that can discriminate between positive and negative examples as a function of the features.': 1.355263157894737,
#  'Some classifiers make a binary classification for a test example, while others assign a probability of being a keyphrase.': 1.3947368421052633,
#  'For instance, in the above text, we might learn a rule that says phrases with initial capital letters are likely to be keyphrases.': 2.4605263157894726,
#  'After training a learner, we can select keyphrases for test documents in the following manner.': 2.328947368421052,
#  'We apply the same example-generation strategy to the test documents, then run each example through the learner.': 1.526315789473684,
#  'We can determine the keyphrases by looking at binary classification decisions or probabilities returned from our learned model.': 1.8157894736842097,
#  'If probabilities are given, a threshold is used to select the keyphrases.': 1.776315789473684,
#  'Keyphrase extractors are generally evaluated using precision and recall.': 1.289473684210526,
#  'Precision measures how many of the proposed keyphrases are actually correct.': 1.6578947368421049,
#  'Recall measures how many of the true keyphrases your system proposed.': 1.8289473684210524,
#  'The two measures can be combined in an F-score, which is the harmonic mean of the two (F = 2PR/(P + R) ).': 0.736842105263158,
#  'Matches between the proposed keyphrases and the known keyphrases can be checked after stemming or applying some other text normalization.': 2.2894736842105257,
#  'Designing a supervised keyphrase extraction system involves deciding on several choices (some of these apply to unsupervised, too).': 1.7499999999999996,
#  'The first choice is exactly how to generate examples.': 0.9078947368421053,
#  'Turney and others have used all possible unigrams, bigrams, and trigrams without intervening punctuation and after removing stopwords.': 1.5789473684210527,
#  'Hulth showed that you can get some improvement by selecting examples to be sequences of tokens that match certain patterns of part-of-speech tags.': 1.2763157894736845,
#  'Ideally, the mechanism for generating examples produces all the known labeled keyphrases as candidates, though this is often not the case.': 2.473684210526314,
#  'For example, if we use only unigrams, bigrams, and trigrams, then we will never be able to extract a known keyphrase containing four words.': 2.06578947368421,
#  'Thus, recall may suffer.': 0.49999999999999994,
#  'However, generating too many examples can also lead to low precision.': 1.3815789473684206,
#  'We also need to create features that describe the examples and are informative enough to allow a learning algorithm to discriminate keyphrases from non- keyphrases.': 2.986842105263156,
#  'Typically features involve various term frequencies (how many times a phrase appears in the current text or in a larger corpus), the length of the example, relative position of the first occurrence, various boolean syntactic features (e.g., contains all caps), etc.': 2.934210526315788,
#  'The Turney paper used about 12 such features.': 0.9605263157894739,
#  "Hulth uses a reduced set of features, which were found most successful in the KEA (Keyphrase Extraction Algorithm) work derived from Turney's seminal paper.": 2.460526315789472,
#  'In the end, the system will need to return a list of keyphrases for a test document, so we need to have a way to limit the number.': 2.460526315789473,
#  'Ensemble methods (i.e., using votes from several classifiers) have been used to produce numeric scores that can be thresholded to provide a user-provided number of keyphrases.': 2.9605263157894726,
#  'This is the technique used by Turney with C4.5 decision trees.': 0.736842105263158,
#  'Hulth used a single binary classifier so the learning algorithm implicitly determines the appropriate number.': 1.6052631578947363,
#  'Once examples and features are created, we need a way to learn to predict keyphrases.': 2.3552631578947363,
#  'Virtually any supervised learning algorithm could be used, such as decision trees, Naive Bayes, and rule induction.': 1.7105263157894737,
#  "In the case of Turney's GenEx algorithm, a genetic algorithm is used to learn parameters for a domain-specific keyphrase extraction algorithm.": 2.3552631578947354,
#  'The extractor follows a series of heuristics to identify keyphrases.': 1.3421052631578947,
#  'The genetic algorithm optimizes parameters for these heuristics with respect to performance on training documents with known key phrases.': 2.0394736842105265,
#  'Another keyphrase extraction algorithm is TextRank.': 2.2499999999999996,
#  'While supervised methods have some nice properties, like being able to produce interpretable rules for what features characterize a keyphrase, they also require a large amount of training data.': 2.657894736842103,
#  'Many documents with known keyphrases are needed.': 2.289473684210526,
#  "Furthermore, training on a specific domain tends to customize the extraction process to that domain, so the resulting classifier is not necessarily portable, as some of Turney's results demonstrate.": 1.802631578947368,
#  'Unsupervised keyphrase extraction removes the need for training data.': 1.6842105263157894,
#  'It approaches the problem from a different angle.': 0.7368421052631581,
#  'Instead of trying to learn explicit features that characterize keyphrases, the TextRank algorithm exploits the structure of the text itself to determine keyphrases that appear "central" to the text in the same way that PageRank selects important Web pages.': 3.64473684210526,
#  'Recall this is based on the notion of "prestige" or "recommendation" from social networks.': 1.1842105263157898,
#  "In this way, TextRank does not rely on any previous training data at all, but rather can be run on any arbitrary piece of text, and it can produce output simply based on the text's intrinsic properties.": 2.5921052631578934,
#  'Thus the algorithm is easily portable to new domains and languages.': 1.1710526315789473,
#  'TextRank is a general purpose graph-based ranking algorithm for NLP.': 2.1578947368421053,
#  'Essentially, it runs PageRank on a graph specially designed for a particular NLP task.': 1.131578947368421,
#  'For keyphrase extraction, it builds a graph using some set of text units as vertices.': 2.5789473684210513,
#  'Edges are based on some measure of semantic or lexical similarity between the text unit vertices.': 1.907894736842105,
#  'Unlike PageRank, the edges are typically undirected and can be weighted to reflect a degree of similarity.': 1.1973684210526319,
#  'Once the graph is constructed, it is used to form a stochastic matrix, combined with a damping factor (as in the "random surfer model"), and the ranking over vertices is obtained by finding the eigenvector corresponding to eigenvalue 1 (i.e., the stationary distribution of the random walk on the graph).': 1.9868421052631584,
#  'The vertices should correspond to what we want to rank.': 0.5263157894736841,
#  'Potentially, we could do something similar to the supervised methods and create a vertex for each unigram, bigram, trigram, etc.': 1.5394736842105265,
#  'However, to keep the graph small, the authors decide to rank individual unigrams in a first step, and then include a second step that merges highly ranked adjacent unigrams to form multi-word phrases.': 2.1315789473684204,
#  'This has a nice side effect of allowing us to produce keyphrases of arbitrary length.': 1.6578947368421046,
#  'For example, if we rank unigrams and find that "advanced", "natural", "language", and "processing" all get high ranks, then we would look at the original text and see that these words appear consecutively and create a final keyphrase using all four together.': 3.8421052631578925,
#  'Note that the unigrams placed in the graph can be filtered by part of speech.': 0.9342105263157894,
#  'The authors found that adjectives and nouns were the best to include.': 0.4605263157894735,
#  'Thus, some linguistic knowledge comes into play in this step.': 0.6710526315789472,
#  'Edges are created based on word co-occurrence in this application of TextRank.': 2.0131578947368425,
#  'Two vertices are connected by an edge if the unigrams appear within a window of size N in the original text.': 2.0,
#  'N is typically around 2–10.': 0.25,
#  'Thus, "natural" and "language" might be linked in a text about NLP.': 1.473684210526316,
#  '"Natural" and "processing" would also be linked because they would both appear in the same string of N words.': 1.4868421052631577,
#  'These edges build on the notion of "text cohesion" and the idea that words that appear near each other are likely related in a meaningful way and "recommend" each other to the reader.': 2.131578947368421,
#  'Since this method simply ranks the individual vertices, we need a way to threshold or produce a limited number of keyphrases.': 2.3552631578947363,
#  'The technique chosen is to set a count T to be a user-specified fraction of the total number of vertices in the graph.': 1.4210526315789473,
#  'Then the top T vertices/unigrams are selected based on their stationary probabilities.': 1.1447368421052635,
#  'A post- processing step is then applied to merge adjacent instances of these T unigrams.': 1.0921052631578947,
#  'As a result, potentially more or less than T final keyphrases will be produced, but the number should be roughly proportional to the length of the original text.': 2.6447368421052615,
#  'It is not initially clear why applying PageRank to a co-occurrence graph would produce useful keyphrases.': 2.460526315789473,
#  'One way to think about it is the following.': 0.6842105263157896,
#  'A word that appears multiple times throughout a text may have many different co-occurring neighbors.': 2.0394736842105265,
#  'For example, in a text about machine learning, the unigram "learning" might co-occur with "machine", "supervised", "un-supervised", and "semi-supervised" in four different sentences.': 2.894736842105262,
#  'Thus, the "learning" vertex would be a central "hub" that connects to these other modifying words.': 1.2236842105263157,
#  'Running PageRank/TextRank on the graph is likely to rank "learning" highly.': 2.1184210526315788,
#  'Similarly, if the text contains the phrase "supervised classification", then there would be an edge between "supervised" and "classification".': 1.894736842105263,
#  'If "classification" appears several other places and thus has many neighbors, its importance would contribute to the importance of "supervised".': 1.5263157894736843,
#  'If it ends up with a high rank, it will be selected as one of the top T unigrams, along with "learning" and probably "classification".': 1.5394736842105263,
#  'In the final post-processing step, we would then end up with keyphrases "supervised learning" and "supervised classification".': 2.3552631578947363,
#  'In short, the co-occurrence graph will contain densely connected regions for terms that appear often and in different contexts.': 1.8947368421052633,
#  'A random walk on this graph will have a stationary distribution that assigns large probabilities to the terms in the centers of the clusters.': 1.0526315789473686,
#  'This is similar to densely connected Web pages getting ranked highly by PageRank.': 1.0921052631578945,
#  'This approach has also been used in document summarization, considered below.': 2.605263157894736,
#  'Like keyphrase extraction, document summarization aims to identify the essence of a text.': 3.3421052631578942,
#  'The only real difference is that now we are dealing with larger text units—whole sentences instead of words and phrases.': 2.184210526315789,
#  'Supervised text summarization is very much like supervised keyphrase extraction.': 2.9605263157894735,
#  'Basically, if you have a collection of documents and human-generated summaries for them, you can learn features of sentences that make them good candidates for inclusion in the summary.': 3.2631578947368403,
#  'Features might include the position in the document (i.e., the first few sentences are probably important), the number of words in the sentence, etc.': 2.6578947368421044,
#  'The main difficulty in supervised extractive summarization is that the known summaries must be manually created by extracting sentences so the sentences in an original training document can be labeled as "in summary" or "not in summary".': 4.36842105263158,
#  'This is not typically how people create summaries, so simply using journal abstracts or existing summaries is usually not sufficient.': 1.3026315789473681,
#  'The sentences in these summaries do not necessarily match up with sentences in the original text, so it would be difficult to assign labels to examples for training.': 2.9999999999999987,
#  'Note, however, that these natural summaries can still be used for evaluation purposes, since ROUGE-1 evaluation only considers unigrams.': 1.9342105263157894,
#  'During the DUC 2001 and 2002 evaluation workshops, TNO developed a sentence extraction system for multi-document summarization in the news domain.': 3.5789473684210513,
#  'The system was based on a hybrid system using a Naive Bayes classifier and statistical language models for modeling salience.': 1.5526315789473688,
#  'Although the system exhibited good results, the researchers wanted to explore the effectiveness of a maximum entropy (ME) classifier for the meeting summarization task, as ME is known to be robust against feature dependencies.': 2.5263157894736823,
#  'Maximum entropy has also been applied successfully for summarization in the broadcast news domain.': 2.210526315789472,
#  'A promising approach is adaptive document/text summarization.': 2.5394736842105257,
#  'It involves first recognizing the text genre and then applying summarization algorithms optimized for this genre.': 2.749999999999999,
#  'Such software has been created.': 0.4210526315789473,
#  'The unsupervised approach to summarization is also quite similar in spirit to unsupervised keyphrase extraction and gets around the issue of costly training data.': 3.3289473684210504,
#  'Some unsupervised summarization approaches are based on finding a "centroid" sentence, which is the mean word vector of all the sentences in the document.': 3.355263157894735,
#  'Then the sentences can be ranked with regard to their similarity to this centroid sentence.': 1.2763157894736845,
#  'A more principled way to estimate sentence importance is using random walks and eigenvector centrality.': 1.236842105263158,
#  'LexRank is an algorithm essentially identical to TextRank, and both use this approach for document summarization.': 3.3684210526315774,
#  'The two methods were developed by different groups at the same time, and LexRank simply focused on summarization, but could just as easily be used for keyphrase extraction or any other NLP ranking task.': 3.7105263157894726,
#  'In both LexRank and TextRank, a graph is constructed by creating a vertex for each sentence in the document.': 2.407894736842105,
#  'The edges between sentences are based on some form of semantic similarity or content overlap.': 1.9078947368421055,
#  "While LexRank uses cosine similarity of TF-IDF vectors, TextRank uses a very similar measure based on the number of words two sentences have in common (normalized by the sentences' lengths).": 3.434210526315788,
#  'The LexRank paper explored using unweighted edges after applying a threshold to the cosine values, but also experimented with using edges with weights equal to the similarity score.': 1.907894736842105,
#  'TextRank uses continuous similarity scores as weights.': 1.842105263157895,
#  'In both algorithms, the sentences are ranked by applying PageRank to the resulting graph.': 1.9210526315789476,
#  'A summary is formed by combining the top ranking sentences, using a threshold or length cutoff to limit the size of the summary.': 1.9868421052631577,
#  'It is worth noting that TextRank was applied to summarization exactly as described here, while LexRank was used as part of a larger summarization system (MEAD) that combines the LexRank score (stationary probability) with other features like sentence position and length using a linear combination with either user-specified or automatically tuned weights.': 4.9473684210526345,
#  'In this case, some training documents might be needed, though the TextRank results show the additional features are not absolutely necessary.': 3.052631578947367,
#  'Unlike TextRank, LexRank has been applied to multi-document summarization.': 3.2368421052631566,
#  'Multi-document summarization is an automatic procedure aimed at extraction of information from multiple texts written about the same topic.': 3.6842105263157876,
#  'Resulting summary report allows individual users, such as professional information consumers, to quickly familiarize themselves with information contained in a large cluster of documents.': 2.328947368421051,
#  'In such a way, multi-document summarization systems are complementing the news aggregators performing the next step down the road of coping with information overload.': 3.223684210526314,
#  'Multi-document summarization may also be done in response to a question.': 2.5263157894736836,
#  'Multi-document summarization creates information reports that are both concise and comprehensive.': 2.4999999999999987,
#  'With different opinions being put together and outlined, every topic is described from multiple perspectives within a single document.': 1.6842105263157892,
#  'While the goal of a brief summary is to simplify information search and cut the time by pointing to the most relevant source documents, comprehensive multi-document summary should itself contain the required information, hence limiting the need for accessing original files to cases when refinement is required.': 2.9342105263157867,
#  'Automatic summaries present information extracted from multiple sources algorithmically, without any editorial touch or subjective human intervention, thus making it completely unbiased.': 2.434210526315788,
#  '[dubious – discuss] Multi-document extractive summarization faces a problem of redundancy.': 2.368421052631578,
#  'Ideally, we want to extract sentences that are both "central" (i.e., contain the main ideas) and "diverse" (i.e., they differ from one another).': 1.513157894736842,
#  'For example, in a set of news articles about some event, each article is likely to have many similar sentences.': 2.3289473684210527,
#  'To address this issue, LexRank applies a heuristic post-processing step that adds sentences in rank order, but discards sentences that are too similar to ones already in the summary.': 2.3421052631578934,
#  'This method is called Cross-Sentence Information Subsumption (CSIS).': 0.9210526315789475,
#  'These methods work based on the idea that sentences "recommend" other similar sentences to the reader.': 1.7763157894736845,
#  'Thus, if one sentence is very similar to many others, it will likely be a sentence of great importance.': 1.4473684210526316,
#  'Its importance also stems from the importance of the sentences "recommending" it.': 1.3947368421052633,
#  'Thus, to get ranked highly and placed in a summary, a sentence must be similar to many sentences that are in turn also similar to many other sentences.': 2.421052631578947,
#  'This makes intuitive sense and allows the algorithms to be applied to an arbitrary new text.': 1.6447368421052633,
#  'The methods are domain-independent and easily portable.': 0.8947368421052632,
#  'One could imagine the features indicating important sentences in the news domain might vary considerably from the biomedical domain.': 2.368421052631578,
#  'However, the unsupervised "recommendation"-based approach applies to any domain.': 1.3421052631578951,
#  'A related method is Maximal Marginal Relevance (MMR), which uses a general-purpose graph-based ranking algorithm like Page/Lex/TextRank that handles both "centrality" and "diversity" in a unified mathematical framework based on absorbing Markov chain random walks (a random walk where certain states end the walk).': 3.460526315789472,
#  'The algorithm is called GRASSHOPPER.': 0.5526315789473684,
#  'In addition to explicitly promoting diversity during the ranking process, GRASSHOPPER incorporates a prior ranking (based on sentence position in the case of summarization).': 2.4868421052631575,
#  'The state of the art results for multi-document summarization are obtained using mixtures of submodular functions.': 3.171052631578946,
#  'These methods have achieved the state of the art results for Document Summarization Corpora, DUC 04 - 07.': 2.5657894736842106,
#  'Similar results were achieved with the use of determinantal point processes (which are a special case of submodular functions) for DUC-04.': 1.9605263157894735,
#  'A new method for multi-lingual multi-document summarization that avoids redundancy generates ideograms to represent the meaning of each sentence in each document, then evaluates similarity by comparing ideogram shape and position.': 3.1842105263157867,
#  'It does not use word frequency, training or preprocessing.': 0.8684210526315791,
#  'It uses two user-supplied parameters: equivalence (when are two sentences to be considered equivalent?)': 1.473684210526316,
#  'and relevance (how long is the desired summary?).': 0.736842105263158,
#  'The idea of a submodular set function has recently emerged as a powerful modeling tool for various summarization problems.': 2.6710526315789456,
#  'Submodular functions naturally model notions of coverage, information, representation and diversity.': 1.9473684210526312,
#  'Moreover, several important combinatorial optimization problems occur as special instances of submodular optimization.': 1.473684210526316,
#  'For example, the set cover problem is a special case of submodular optimization, since the set cover function is submodular.': 1.9210526315789473,
#  'The set cover function attempts to find a subset of objects which cover a given set of concepts.': 1.1578947368421055,
#  'For example, in document summarization, one would like the summary to cover all important and relevant concepts in the document.': 3.368421052631578,
#  'This is an instance of set cover.': 0.7105263157894738,
#  'Similarly, the facility location problem is a special case of submodular functions.': 1.5526315789473684,
#  'The Facility Location function also naturally models coverage and diversity.': 1.460526315789474,
#  'Another example of a submodular optimization problem is using a determinantal point process to model diversity.': 1.9342105263157896,
#  'Similarly, the Maximum-Marginal-Relevance procedure can also be seen as an instance of submodular optimization.': 1.4999999999999998,
#  'All these important models encouraging coverage, diversity and information are all submodular.': 1.6710526315789471,
#  'Moreover, submodular functions can be efficiently combined, and the resulting function is still submodular.': 1.2763157894736838,
#  'Hence, one could combine one submodular function which models diversity, another one which models coverage and use human supervision to learn a right model of a submodular function for the problem.': 2.3157894736842097,
#  'While submodular functions are fitting problems for summarization, they also admit very efficient algorithms for optimization.': 2.9736842105263146,
#  'For example, a simple greedy algorithm admits a constant factor guarantee.': 1.0131578947368423,
#  'Moreover, the greedy algorithm is extremely simple to implement and can scale to large datasets, which is very important for summarization problems.': 2.6052631578947363,
#  'Submodular functions have achieved state-of-the-art for almost all summarization problems.': 2.3684210526315783,
#  'For example, work by Lin and Bilmes, 2012 shows that submodular functions achieve the best results to date on DUC-04, DUC-05, DUC-06 and DUC-07 systems for document summarization.': 3.5263157894736827,
#  'Similarly, work by Lin and Bilmes, 2011, shows that many existing systems for automatic summarization are instances of submodular functions.': 3.1842105263157876,
#  'This was a breakthrough result establishing submodular functions as the right models for summarization problems.': 2.513157894736841,
#  '[citation needed] Submodular Functions have also been used for other summarization tasks.': 2.789473684210525,
#  'Tschiatschek et al., 2014 show that mixtures of submodular functions achieve state-of-the-art results for image collection summarization.': 2.6447368421052624,
#  'Similarly, Bairi et al., 2015 show the utility of submodular functions for summarizing multi-document topic hierarchies.': 2.210526315789473,
#  'Submodular Functions have also successfully been used for summarizing machine learning datasets.': 2.4473684210526305,
#  'Specific applications of automatic summarization include: The most common way to evaluate the informativeness of automatic summaries is to compare them with human-made model summaries.': 2.8289473684210513,
#  'Evaluation can be intrinsic or extrinsic, and inter-textual or intra-textual.': 1.2631578947368425,
#  'Intrinsic evaluation assesses the summaries directly, while extrinsic evaluation evaluates how the summarization system affects the completion of some other task.': 2.38157894736842,
#  'Intrinsic evaluations have assessed mainly the coherence and informativeness of summaries.': 1.118421052631579,
#  'Extrinsic evaluations, on the other hand, have tested the impact of summarization on tasks like relevance assessment, reading comprehension, etc.': 2.289473684210525,
#  'Intra-textual evaluation assess the output of a specific summarization system, while inter-textual evaluation focuses on contrastive analysis of outputs of several summarization systems.': 3.144736842105262,
#  'Human judgement often varies greatly in what it considers a "good" summary, so creating an automatic evaluation process is particularly difficult.': 1.8157894736842102,
#  'Manual evaluation can be used, but this is both time and labor-intensive, as it requires humans to read not only the summaries but also the source documents.': 2.513157894736841,
#  'Other issues are those concerning coherence and coverage.': 0.5526315789473684,
#  'The most common way to evaluate summaries is ROUGE (Recall-Oriented Understudy for Gisting Evaluation).': 1.3684210526315788,
#  "It is very common for summarization and translation systems in NIST's Document Understanding Conferences.": 2.328947368421052,
#  'ROUGE is a recall-based measure of how well a summary covers the content of human-generated summaries known as references.': 2.3684210526315783,
#  'It calculates n-gram overlaps between automatically generated summaries and previously written human summaries.': 1.3947368421052628,
#  'It is recall-based to encourage inclusion of all important topics in summaries.': 1.4605263157894737,
#  'Recall can be computed with respect to unigram, bigram, trigram, or 4-gram matching.': 0.7500000000000001,
#  'For example, ROUGE-1 is the fraction of unigrams that appear in both the reference summary and the automatic summary out of all unigrams in the reference summary.': 1.6973684210526314,
#  'If there are multiple reference summaries, their scores are averaged.': 1.1184210526315792,
#  'A high level of overlap should indicate a high degree of shared concepts between the two summaries.': 1.0789473684210524,
#  'ROUGE cannot determine if the result is coherent, that is if sentences flow together in a sensibly.': 1.289473684210526,
#  'High-order n-gram ROUGE measures help to some degree.': 0.6184210526315789,
#  'Another unsolved problem is Anaphor resolution.': 0.4868421052631578,
#  'Similarly, for image summarization, Tschiatschek et al., developed a Visual-ROUGE score which judges the performance of algorithms for image summarization.': 2.486842105263157,
#  'Domain-independent summarization techniques apply sets of general features to identify information-rich text segments.': 3.368421052631577,
#  "Recent research focuses on domain-specific summarization using knowledge specific to the text's domain, such as medical knowledge and ontologies for summarizing medical texts.": 3.0657894736842093,
#  'The main drawback of the evaluation systems so far is that we need a reference summary (for some methods, more than one), to compare automatic summaries with models.': 2.697368421052631,
#  'This is a hard and expensive task.': 0.30263157894736836,
#  'Much effort has to be made to create corpora of texts and their corresponding summaries.': 1.6315789473684212,
#  'Furthermore, some methods require manual annotation of the summaries (e.g.': 0.9868421052631579,
#  'SCU in the Pyramid Method).': 0.3421052631578947,
#  'Moreover, they all perform a quantitative evaluation with regard to different similarity metrics.': 1.0921052631578945,
#  'The first publication in the area dates back to 1957 (Hans Peter Luhn), starting with a statistical technique.': 0.710526315789474,
#  'Research increased significantly in 2015.': 0.39473684210526305,
#  'Term frequency–inverse document frequency had been used by 2016.': 1.1710526315789471,
#  'Pattern-based summarization was the most powerful option for multi-document summarization found by 2016.': 2.3552631578947363,
#  'In the following year it was surpassed by latent semantic analysis (LSA) combined with non-negative matrix factorization (NMF).': 0.8157894736842107,
#  'Although they did not replace other approaches and are often combined with them, by 2019 machine learning methods dominated the extractive summarization of single documents, which was considered to be nearing maturity.': 3.447368421052629,
#  'By 2020, the field was still very active and research is shifting towards abstractive summation and real-time summarization.': 1.6973684210526314,
#  'Recently the rise of transformer models replacing more traditional RNN (LSTM) have provided a flexibility in the mapping of text sequences to text sequences of a different type, which is well suited to automatic summarization.': 2.9342105263157867,
#  'This includes models such as T5 and Pegasus.': 0.6184210526315789}

# %%
avg_score = sum([sentence_scores[sent] for sent in sentence_scores]) / len(sentence_scores)

# %%
avg_score
# Out:
# 2.05751034890597

# %%
summary = []
for sent in sentence_list:
    if (sent in sentence_scores) and (sentence_scores[sent] > (1.2 * avg_score)):
        summary.append(sent)

# %%
final = " ".join(summary)

# %%
final
# Out:
# 'Automatic summarization is the process of shortening a set of data computationally, to create a subset (a summary) that represents the most important or relevant information within the original content. Text summarization is usually implemented by natural language processing methods, designed to locate the most informative sentences in a given document. Image summarization is the subject of ongoing research; existing approaches typically attempt to display the most representative images from a given image collection, or generate a video that only includes the most important content from the entire collection. Video summarization algorithms identify and extract from the original video content the most important frames (key-frames), and/or the most important video segments (key-shots), normally in a temporally ordered fashion. Video summaries simply retain a carefully selected subset of the original video frames and, therefore, are not identical to the output of video synopsis algorithms, where new video frames are being synthesized based on the original video content. Examples of extracted content include key-phrases that can be used to "tag" or index a text document, or key sentences (including headings) that collectively comprise an abstract, and representative images or video segments, as stated above. For text, extraction is analogous to the process of skimming, where the summary (if available), headings and subheadings, figures, the first and last paragraphs of a section, and optionally the first and last sentences in a paragraph are read before one chooses to read the entire document in detail. Other examples of extraction that include key sequences of text in terms of clinical relevance (including patient/problem, intervention, and outcome). Abstractive summarization methods generate new text that did not exist in the original text. Abstractive methods build an internal semantic representation of the original content (often called a language model), and then use this representation to create a summary that is closer to what a human might express. Such transformation, however, is computationally much more challenging than extraction, involving both natural language processing and often a deep understanding of the domain of the original text in cases where the original document relates to a special field of knowledge. In Machine Aided Human Summarization, extractive techniques highlight candidate passages for inclusion (to which the human adds or removes text). In Human Aided Machine Summarization, a human post-processes software output, in the same way that one edits the output of automatic translation by Google Translate. The first is generic summarization, which focuses on obtaining a generic summary or abstract of the collection (whether documents, or sets of images, or videos, news stories etc.). Summarization systems are able to create both query relevant text summaries and generic machine-generated summaries depending on what the user needs. An example of a summarization problem is document summarization, which attempts to automatically produce an abstract from a given document. Sometimes one might be interested in generating a summary from a single source document, while others can use multiple source documents (for example, a cluster of articles on the same topic). At a very high level, summarization algorithms try to find subsets of objects (like set of sentences, or a set of images), which cover information of the entire set. Some techniques and algorithms which naturally model summarization problems are TextRank and PageRank, Submodular set function, Determinantal point process, maximal marginal relevance (MMR) etc. In the case of research articles, many authors provide manually assigned keywords, but most text lacks pre-existing keyphrases. For example, news articles rarely have keyphrases attached, but it would be useful to be able to automatically do so for a number of applications discussed below. Consider ...

# %%
len(final)
# Out:
# 14525

# %%
len(formatted_article_content)
# Out:
# 32311
