# %%
import re
import urllib.request
import bs4 as BeautifulSoup
import nltk
import heapq
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\efecank\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\efecank\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
stop_words = stopwords.words('english')

# %%
scraped_data = urllib.request.urlopen('https://en.wikipedia.org/wiki/Python_(programming_language)')

# %%
article = scraped_data.read()

# %%
article_parsed = BeautifulSoup.BeautifulSoup(article,'lxml')

# %%
paragraphs = article_parsed.find_all('p')

# %%
article_content = ''
for p in paragraphs:
    article_content += p.text

# %%
article_content = re.sub(r'\[[0-9]*\]', ' ', article_content)
article_content = re.sub(r'\s+', ' ', article_content)

# %%
formatted_article_content = re.sub('[^a-zA-Z]', ' ', article_content )
formatted_article_content = re.sub(r'\s+', ' ', formatted_article_content)

# %%
words = word_tokenize(formatted_article_content)

# %%
word_frequencies = {}

for word in words:
    word = word.lower()
    if word not in stop_words:
        if word not in word_frequencies.keys():
            word_frequencies[word] = 1
        else:
            word_frequencies[word] += 1

# %%
word_frequencies
# Out:
# {'python': 168,
#  'high': 3,
#  'level': 2,
#  'general': 2,
#  'purpose': 1,
#  'programming': 23,
#  'language': 32,
#  'design': 6,
#  'philosophy': 5,
#  'emphasizes': 1,
#  'code': 16,
#  'readability': 2,
#  'use': 16,
#  'significant': 1,
#  'indentation': 6,
#  'dynamically': 3,
#  'typed': 5,
#  'garbage': 4,
#  'collected': 1,
#  'supports': 4,
#  'multiple': 3,
#  'paradigms': 2,
#  'including': 15,
#  'structured': 2,
#  'particularly': 3,
#  'procedural': 1,
#  'object': 10,
#  'oriented': 6,
#  'functional': 4,
#  'often': 8,
#  'described': 1,
#  'batteries': 2,
#  'included': 1,
#  'due': 5,
#  'comprehensive': 1,
#  'standard': 15,
#  'library': 12,
#  'guido': 4,
#  'van': 7,
#  'rossum': 7,
#  'began': 2,
#  'working': 1,
#  'late': 3,
#  'successor': 2,
#  'abc': 3,
#  'first': 4,
#  'released': 9,
#  'major': 5,
#  'revision': 1,
#  'completely': 1,
#  'backward': 1,
#  'compatible': 1,
#  'earlier': 1,
#  'versions': 8,
#  'last': 1,
#  'release': 5,
#  'consistently': 2,
#  'ranks': 1,
#  'one': 9,
#  'popular': 4,
#  'languages': 18,
#  'gained': 1,
#  'widespread': 1,
#  'machine': 3,
#  'learning': 2,
#  'community': 6,
#  'invented': 1,
#  'centrum': 1,
#  'wiskunde': 1,
#  'informatica': 1,
#  'cwi': 1,
#  'netherlands': 1,
#  'inspired': 1,
#  'setl': 1,
#  'capable': 1,
#  'exception': 2,
#  'handling': 3,
#  'interfacing': 1,
#  'amoeba': 1,
#  'operating': 3,
#  'system': 5,
#  'implementation': 7,
#  'december': 3,
#  'shouldered': 1,
#  'sole': 1,
#  'responsibility': 1,
#  'project': 4,
#  'lead': 2,
#  'developer': 1,
#  'july': 1,
#  'announced': 2,
#  'permanent': 1,
#  'vacation': 1,
#  'responsibilities': 1,
#  'benevolent': 2,
#  'dictator': 2,
#  'life': 4,
#  'bdfl': 2,
#  'title': 1,
#  'bestowed': 1,
#  'upon': 1,
#  'reflect': 1,
#  'long': 1,
#  'term': 1,
#  'commitment': 1,
#  'chief': 1,
#  'decision': 1,
#  'maker': 1,
#  'since': 11,
#  'come': 2,
#  'retirement': 1,
#  'self': 4,
#  'titled': 1,
#  'emeritus': 1,
#  'january': 2,
#  'active': 2,
#  'core': 5,
#  'developers': 5,
#  'elected': 1,
#  'five': 1,
#  'member': 1,
#  'steering': 2,
#  'council': 2,
#  'october': 2,
#  'many': 19,
#  'new': 9,
#  'features': 8,
#  'list': 4,
#  'comprehensions': 3,
#  'cycle': 2,
#  'detecting': 2,
#  'collection': 2,
#  'reference': 9,
#  'counting': 2,
#  'unicode': 1,
#  'support': 17,
#  'backported': 2,
#  'x': 4,
#  'releases': 5,
#  'include': 10,
#  'utility': 1,
#  'automates': 1,
#  'translation': 1,
#  'end': 3,
#  'initially': 1,
#  'set': 2,
#  'postponed': 1,
#  'concern': 1,
#  'large': 6,
#  'body': 1,
#  'existing': 2,
#  'could': 1,
#  'easily': 3,
#  'forward': 1,
#  'ported': 1,
#  'security': 12,
#  'patches': 2,
#  'improvements': 1,
#  'currently': 1,
#  'later': 2,
#  'supported': 7,
#  'issues': 7,
#  'fixed': 2,
#  'e': 10,
#  'g': 8,
#  'final': 2,
#  'older': 4,
#  'officially': 1,
#  'unsupported': 2,
#  'different': 2,
#  'unofficial': 2,
#  'pypy': 3,
#  'continues': 1,
#  'plus': 2,
#  'meaning': 3,
#  'least': 3,
#  'updates': 2,
#  'twice': 1,
#  'expedited': 2,
#  'insecure': 1,
#  'leading': 1,
#  'possible': 3,
#  'remote': 1,
#  'execution': 4,
#  'web': 8,
#  'cache': 1,
#  'poisoning': 1,
#  'may': 6,
#  'series': 2,
#  'joining': 1,
#  'would': 4,
#  'receive': 2,
#  'fixes': 1,
#  'future': 3,
#  'september': 1,
#  'four': 3,
#  'made': 2,
#  'potential': 2,
#  'denial': 1,
#  'service': 1,
#  'attack': 1,
#  'update': 6,
#  'stable': 2,
#  'opposed': 1,
#  'notable': 1,
#  'changes': 2,
#  'increased': 1,
#  'program': 7,
#  'speed': 5,
#  'improved': 4,
#  'error': 2,
#  'reporting': 1,
#  'adds': 4,
#  'syntax': 8,
#  'fact': 1,
#  'every': 1,
#  'soft': 2,
#  'keyword': 2,
#  'type': 12,
#  'recent': 1,
#  'added': 2,
#  'lot': 2,
#  'typing': 7,
#  'union': 1,
#  'operator': 4,
#  'match': 1,
#  'case': 2,
#  'keywords': 3,
#  'structural': 1,
#  'pattern': 2,
#  'matching': 2,
#  'statements': 8,
#  'also': 18,
#  'drops': 1,
#  'outdated': 2,
#  'modules': 8,
#  'functionality': 7,
#  'see': 1,
#  'development': 12,
#  'section': 1,
#  'claims': 2,
#  'faster': 1,
#  'another': 2,
#  'top': 2,
#  'messages': 1,
#  'june': 1,
#  'oldest': 1,
#  'version': 6,
#  'albeit': 1,
#  'phase': 1,
#  'reaching': 1,
#  'introduced': 1,
#  'incremental': 1,
#  'shorter': 1,
#  'pauses': 1,
#  'programs': 6,
#  'objects': 3,
#  'collector': 2,
#  'experimental': 2,
#  'jit': 1,
#  'compiler': 3,
#  'removals': 1,
#  'c': 22,
#  'api': 3,
#  'dead': 1,
#  'deprecated': 5,
#  'classes': 6,
#  'functions': 5,
#  'methods': 6,
#  'removed': 4,
#  'starting': 2,
#  'years': 2,
#  'full': 2,
#  'half': 2,
#  'followed': 1,
#  'total': 1,
#  'multi': 2,
#  'paradigm': 1,
#  'fully': 1,
#  'aspect': 1,
#  'metaprogramming': 2,
#  'metaobjects': 1,
#  'via': 3,
#  'extensions': 4,
#  'contract': 1,
#  'logic': 2,
#  'uses': 12,
#  'dynamic': 5,
#  'combination': 3,
#  'memory': 1,
#  'management': 2,
#  'name': 5,
#  'resolution': 1,
#  'binding': 2,
#  'binds': 2,
#  'method': 4,
#  'variable': 4,
#  'names': 4,
#  'offers': 1,
#  'lisp': 2,
#  'tradition': 1,
#  'filter': 1,
#  'mapandreduce': 1,
#  'dictionaries': 1,
#  'sets': 1,
#  'generator': 3,
#  'expressions': 7,
#  'two': 4,
#  'itertools': 1,
#  'functools': 1,
#  'implement': 1,
#  'tools': 5,
#  'borrowed': 1,
#  'haskell': 1,
#  'ml': 1,
#  'summarized': 1,
#  'zen': 2,
#  'pep': 5,
#  'includes': 4,
#  'aphorisms': 1,
#  'however': 6,
#  'regularly': 1,
#  'violate': 1,
#  'principles': 1,
#  'received': 1,
#  'criticism': 1,
#  'adding': 3,
#  'unnecessary': 1,
#  'bloat': 1,
#  'responses': 1,
#  'criticisms': 1,
#  'guideline': 1,
#  'rather': 5,
#  'rule': 2,
#  'addition': 2,
#  'controversial': 1,
#  'resigned': 1,
#  'following': 1,
#  'vitriol': 1,
#  'assignment': 3,
#  'expression': 6,
#  'nevertheless': 1,
#  'building': 1,
#  'designed': 1,
#  'highly': 1,
#  'extensible': 2,
#  'compact': 1,
#  'modularity': 1,
#  'means': 4,
#  'programmable': 2,
#  'interfaces': 2,
#  'applications': 9,
#  'vision': 2,
#  'small': 1,
#  'interpreter': 2,
#  'stemmed': 1,
#  'frustrations': 1,
#  'espoused': 1,
#  'opposite': 1,
#  'approach': 1,
#  'strive': 2,
#  'simpler': 1,
#  'less': 3,
#  'cluttered': 1,
#  'grammar': 1,
#  'giving': 1,
#  'choice': 2,
#  'coding': 2,
#  'methodology': 1,
#  'contrast': 4,
#  'perl': 1,
#  'way': 3,
#  'motto': 1,
#  'embraces': 1,
#  'preferably': 1,
#  'obvious': 1,
#  'practice': 2,
#  'provides': 6,
#  'ways': 2,
#  'achieve': 1,
#  'task': 1,
#  'example': 9,
#  'three': 3,
#  'format': 3,
#  'string': 2,
#  'literal': 1,
#  'certainty': 1,
#  'programmer': 1,
#  'alex': 1,
#  'martelli': 1,
#  'fellow': 1,
#  'software': 5,
#  'foundation': 2,
#  'book': 1,
#  'author': 1,
#  'wrote': 1,
#  'describe': 1,
#  'something': 2,
#  'clever': 1,
#  'considered': 1,
#  'compliment': 1,
#  'culture': 2,
#  'usually': 1,
#  'avoid': 1,
#  'premature': 1,
#  'optimization': 3,
#  'reject': 1,
#  'non': 2,
#  'critical': 2,
#  'parts': 3,
#  'cpython': 8,
#  'offer': 1,
#  'marginal': 1,
#  'increases': 1,
#  'cost': 1,
#  'clarity': 1,
#  'moving': 1,
#  'extension': 1,
#  'written': 7,
#  'using': 7,
#  'time': 5,
#  'like': 14,
#  'cross': 2,
#  'compile': 2,
#  'either': 2,
#  'provide': 1,
#  'might': 1,
#  'expected': 2,
#  'restricted': 2,
#  'subset': 2,
#  'compiled': 1,
#  'possibly': 1,
#  'semantics': 2,
#  'slightly': 1,
#  'changed': 2,
#  'aim': 1,
#  'fun': 1,
#  'reflected': 1,
#  'tribute': 1,
#  'british': 2,
#  'comedy': 2,
#  'group': 2,
#  'monty': 5,
#  'occasionally': 1,
#  'playful': 1,
#  'approaches': 1,
#  'tutorials': 1,
#  'materials': 1,
#  'terms': 2,
#  'spam': 2,
#  'eggs': 2,
#  'sketch': 1,
#  'examples': 2,
#  'instead': 3,
#  'used': 21,
#  'foo': 2,
#  'bar': 2,
#  'common': 2,
#  'neologism': 1,
#  'pythonic': 2,
#  'wide': 2,
#  'range': 2,
#  'meanings': 1,
#  'related': 3,
#  'style': 5,
#  'idioms': 1,
#  'well': 3,
#  'natural': 3,
#  'show': 3,
#  'fluency': 1,
#  'conform': 1,
#  'minimalist': 1,
#  'emphasis': 1,
#  'difficult': 1,
#  'understand': 1,
#  'reads': 1,
#  'rough': 2,
#  'transcription': 1,
#  'called': 5,
#  'unpythonic': 1,
#  'meant': 1,
#  'readable': 1,
#  'formatting': 1,
#  'visually': 1,
#  'uncluttered': 1,
#  'english': 1,
#  'punctuation': 1,
#  'unlike': 1,
#  'curly': 2,
#  'brackets': 2,
#  'delimit': 2,
#  'blocks': 2,
#  'semicolons': 1,
#  'allowed': 1,
#  'rarely': 1,
#  'fewer': 1,
#  'syntactic': 2,
#  'exceptions': 1,
#  'special': 2,
#  'cases': 1,
#  'pascal': 1,
#  'whitespace': 1,
#  'increase': 1,
#  'comes': 2,
#  'certain': 2,
#  'decrease': 1,
#  'signifies': 1,
#  'current': 2,
#  'block': 1,
#  'thus': 1,
#  'visual': 4,
#  'structure': 2,
#  'accurately': 1,
#  'represents': 1,
#  'semantic': 3,
#  'feature': 2,
#  'sometimes': 2,
#  'termed': 1,
#  'side': 2,
#  'recommended': 1,
#  'indent': 1,
#  'size': 1,
#  'spaces': 1,
#  'statement': 3,
#  'separate': 1,
#  'allocated': 1,
#  'variables': 2,
#  'subsequently': 1,
#  'rebound': 1,
#  'generic': 1,
#  'holder': 1,
#  'without': 1,
#  'data': 8,
#  'always': 2,
#  'refers': 1,
#  'statically': 1,
#  'contain': 2,
#  'value': 1,
#  'tail': 1,
#  'call': 1,
#  'class': 7,
#  'continuations': 1,
#  'according': 1,
#  'never': 1,
#  'better': 1,
#  'coroutine': 1,
#  'provided': 1,
#  'extending': 1,
#  'generators': 5,
#  'lazy': 1,
#  'iterators': 1,
#  'passed': 2,
#  'unidirectionally': 1,
#  'pass': 1,
#  'back': 1,
#  'function': 3,
#  'stack': 1,
#  'levels': 1,
#  'distinction': 1,
#  'rigidly': 1,
#  'enforced': 2,
#  'scheme': 1,
#  'ruby': 2,
#  'leads': 1,
#  'duplicating': 1,
#  'part': 6,
#  'lambda': 1,
#  'particular': 2,
#  'form': 1,
#  'conditional': 2,
#  'attached': 1,
#  'instance': 5,
#  'argument': 2,
#  'normal': 1,
#  'sugar': 3,
#  'explicit': 1,
#  'parameter': 1,
#  'access': 1,
#  'implicit': 1,
#  'java': 4,
#  'objective': 1,
#  'dunder': 1,
#  'beginning': 1,
#  'ending': 1,
#  'double': 1,
#  'underscores': 1,
#  'allow': 2,
#  'user': 4,
#  'defined': 3,
#  'modify': 1,
#  'handled': 1,
#  'native': 3,
#  'operations': 5,
#  'length': 1,
#  'comparison': 2,
#  'arithmetic': 4,
#  'conversion': 1,
#  'duck': 1,
#  'untyped': 1,
#  'constraints': 1,
#  'checked': 1,
#  'fail': 1,
#  'signifying': 1,
#  'suitable': 1,
#  'despite': 1,
#  'strongly': 1,
#  'forbidding': 1,
#  'number': 3,
#  'silently': 1,
#  'attempting': 1,
#  'make': 1,
#  'sense': 1,
#  'allows': 2,
#  'programmers': 1,
#  'define': 1,
#  'types': 2,
#  'instances': 2,
#  'constructed': 1,
#  'calling': 1,
#  'spamclass': 1,
#  'eggsclass': 1,
#  'metaclass': 1,
#  'allowing': 1,
#  'reflection': 1,
#  'kinds': 1,
#  'old': 1,
#  'optional': 1,
#  'annotations': 3,
#  'external': 1,
#  'mypy': 2,
#  'catch': 1,
#  'errors': 1,
#  'mypyc': 1,
#  'leverages': 1,
#  'usual': 1,
#  'symbols': 1,
#  'operators': 3,
#  'floor': 2,
#  'division': 7,
#  'modulo': 1,
#  'operation': 1,
#  'remainder': 1,
#  'negative': 5,
#  'exponentiation': 1,
#  'matrix': 1,
#  'multiplication': 1,
#  'work': 1,
#  'traditional': 2,
#  'math': 2,
#  'precedence': 1,
#  'rules': 1,
#  'infix': 1,
#  'unary': 1,
#  'represent': 1,
#  'positive': 4,
#  'numbers': 4,
#  'respectively': 2,
#  'integers': 1,
#  'produces': 1,
#  'floating': 2,
#  'point': 2,
#  'results': 2,
#  'behavior': 1,
#  'significantly': 1,
#  'true': 2,
#  'simply': 1,
#  'classic': 1,
#  'rounding': 3,
#  'towards': 1,
#  'infinity': 1,
#  'though': 1,
#  'consistency': 1,
#  'equation': 3,
#  'b': 15,
#  'valid': 1,
#  'values': 1,
#  'maintaining': 1,
#  'validity': 1,
#  'result': 2,
#  'open': 1,
#  'interval': 2,
#  'integer': 4,
#  'lie': 1,
#  'round': 7,
#  'float': 1,
#  'nearest': 1,
#  'tie': 1,
#  'breaking': 1,
#  'even': 2,
#  'produce': 1,
#  'away': 1,
#  'zero': 1,
#  'boolean': 1,
#  'equality': 1,
#  'relations': 1,
#  'manner': 1,
#  'consistent': 1,
#  'mathematics': 4,
#  'tests': 1,
#  'whether': 1,
#  'derived': 2,
#  'interpret': 1,
#  'differently': 1,
#  'evaluate': 1,
#  'resulting': 1,
#  'compared': 2,
#  'arbitrary': 4,
#  'precision': 4,
#  'decimal': 3,
#  'module': 3,
#  'pre': 1,
#  'several': 4,
#  'modes': 1,
#  'fraction': 1,
#  'fractions': 1,
#  'rational': 1,
#  'extensive': 1,
#  'third': 3,
#  'party': 3,
#  'numpy': 2,
#  'extends': 1,
#  'capabilities': 1,
#  'frequently': 2,
#  'scientific': 3,
#  'scripting': 5,
#  'aid': 1,
#  'problems': 1,
#  'numerical': 3,
#  'processing': 5,
#  'manipulation': 1,
#  'hello': 1,
#  'world': 1,
#  'calculate': 1,
#  'factorial': 1,
#  'suited': 1,
#  'tasks': 1,
#  'commonly': 3,
#  'cited': 1,
#  'greatest': 1,
#  'strengths': 1,
#  'internet': 1,
#  'facing': 1,
#  'formats': 1,
#  'protocols': 1,
#  'mime': 1,
#  'http': 2,
#  'creating': 2,
#  'graphical': 2,
#  'connecting': 1,
#  'relational': 2,
#  'databases': 1,
#  'generating': 1,
#  'pseudorandom': 1,
#  'decimals': 1,
#  'manipulating': 1,
#  'regular': 1,
#  'unit': 2,
#  'testing': 2,
#  'covered': 2,
#  'specifications': 1,
#  'server': 3,
#  'gateway': 2,
#  'interface': 4,
#  'wsgi': 2,
#  'wsgiref': 1,
#  'follows': 1,
#  'specified': 1,
#  'internal': 1,
#  'documentation': 3,
#  'test': 2,
#  'suites': 1,
#  'platform': 2,
#  'need': 2,
#  'altering': 1,
#  'rewriting': 1,
#  'variant': 1,
#  'implementations': 3,
#  'march': 1,
#  'package': 4,
#  'index': 2,
#  'pypi': 1,
#  'official': 2,
#  'repository': 2,
#  'contains': 2,
#  'packages': 2,
#  'read': 1,
#  'eval': 1,
#  'print': 1,
#  'loop': 1,
#  'repl': 1,
#  'permitting': 1,
#  'command': 2,
#  'line': 2,
#  'users': 2,
#  'enter': 1,
#  'sequentially': 1,
#  'immediately': 1,
#  'integrated': 2,
#  'environment': 2,
#  'ide': 4,
#  'idle': 2,
#  'beginner': 1,
#  'shells': 1,
#  'ipython': 1,
#  'add': 1,
#  'abilities': 1,
#  'auto': 1,
#  'completion': 1,
#  'session': 1,
#  'state': 2,
#  'retention': 1,
#  'highlighting': 1,
#  'desktop': 1,
#  'environments': 1,
#  'pycharm': 1,
#  'intellij': 1,
#  'idea': 1,
#  'studio': 1,
#  'etc': 1,
#  'browser': 2,
#  'based': 3,
#  'ides': 1,
#  'sagemath': 2,
#  'developing': 2,
#  'science': 1,
#  'pythonanywhere': 1,
#  'hosting': 1,
#  'canopy': 1,
#  'commercial': 1,
#  'emphasizing': 1,
#  'computing': 2,
#  'meeting': 1,
#  'select': 1,
#  'limited': 1,
#  'implemented': 2,
#  'compiles': 1,
#  'intermediate': 1,
#  'bytecode': 1,
#  'executed': 1,
#  'virtual': 1,
#  'distributed': 1,
#  'mixture': 1,
#  'available': 3,
#  'platforms': 2,
#  'windows': 3,
#  'installer': 4,
#  'deliberately': 1,
#  'fails': 1,
#  'install': 1,
#  'xp': 1,
#  'modern': 1,
#  'unix': 1,
#  'systems': 3,
#  'macos': 1,
#  'apple': 1,
#  'macs': 1,
#  'vms': 1,
#  'portability': 1,
#  'earliest': 1,
#  'priorities': 1,
#  'os': 1,
#  'solaris': 1,
#  'dropped': 3,
#  'threading': 1,
#  'compilers': 2,
#  'developed': 2,
#  'transpilers': 1,
#  'unrestricted': 1,
#  'similar': 1,
#  'source': 2,
#  'specialized': 2,
#  'projects': 3,
#  'latest': 1,
#  'performance': 2,
#  'various': 2,
#  'combinatorial': 1,
#  'workload': 1,
#  'presented': 1,
#  'euroscipy': 1,
#  'benchmarked': 1,
#  'computer': 4,
#  'benchmarks': 1,
#  'game': 1,
#  'conducted': 1,
#  'largely': 1,
#  'enhancement': 2,
#  'proposal': 1,
#  'process': 1,
#  'primary': 2,
#  'mechanism': 1,
#  'proposing': 1,
#  'collecting': 1,
#  'input': 1,
#  'documenting': 1,
#  'decisions': 1,
#  'outstanding': 1,
#  'peps': 1,
#  'reviewed': 1,
#  'commented': 1,
#  'corresponds': 1,
#  'mailing': 1,
#  'dev': 1,
#  'forum': 1,
#  'specific': 2,
#  'originally': 3,
#  'discussed': 1,
#  'roundup': 1,
#  'bug': 1,
#  'tracker': 1,
#  'hosted': 2,
#  'discussions': 1,
#  'migrated': 1,
#  'github': 2,
#  'took': 1,
#  'place': 1,
#  'running': 2,
#  'mercurial': 1,
#  'moved': 1,
#  'public': 1,
#  'distinguished': 1,
#  'incremented': 1,
#  'alpha': 1,
#  'beta': 1,
#  'candidates': 1,
#  'previews': 1,
#  'although': 1,
#  'schedule': 1,
#  'delayed': 1,
#  'ready': 1,
#  'team': 1,
#  'monitors': 1,
#  'suite': 1,
#  'academic': 1,
#  'conference': 1,
#  'pycon': 1,
#  'mentoring': 1,
#  'pyladies': 1,
#  'wstr': 1,
#  'modified': 1,
#  'already': 2,
#  'array': 1,
#  'u': 1,
#  'emit': 2,
#  'deprecationwarning': 2,
#  'w': 1,
#  'ctypes': 1,
#  'cgihttprequesthandler': 1,
#  'bugs': 1,
#  'namedtuple': 1,
#  'arguments': 1,
#  'denote': 1,
#  'fields': 1,
#  'disallowed': 1,
#  'generate': 1,
#  'pydoc': 1,
#  'sphinx': 1,
#  'pdoc': 1,
#  'forks': 1,
#  'doxygen': 1,
#  'graphviz': 1,
#  'among': 1,
#  'others': 1,
#  'creator': 1,
#  'enjoyed': 1,
#  'references': 2,
#  'appear': 1,
#  'metasyntactic': 1,
#  'literature': 1,
#  'routines': 1,
#  'referred': 1,
#  'pythonistas': 1,
#  'prefix': 2,
#  'py': 2,
#  'libraries': 5,
#  'pygame': 1,
#  'sdl': 1,
#  'create': 1,
#  'games': 2,
#  'pyqt': 1,
#  'pygtk': 1,
#  'bind': 1,
#  'qt': 1,
#  'gtk': 1,
#  'ranked': 1,
#  'ten': 1,
#  'tiobe': 1,
#  'ahead': 1,
#  'selected': 1,
#  'year': 2,
#  'highest': 1,
#  'rise': 1,
#  'ratings': 1,
#  'done': 1,
#  'times': 1,
#  'organizations': 1,
#  'wikipedia': 1,
#  'google': 2,
#  'yahoo': 1,
#  'cern': 1,
#  'nasa': 1,
#  ...}

# %%
maximum_frequency = max(word_frequencies.values())

for word in word_frequencies.keys():
    word_frequencies[word] = (word_frequencies[word]/maximum_frequency)

# %%
maximum_frequency
# Out:
# 168

# %%
sentence_list = sent_tokenize(article_content)

# %%
sentence_scores = {}

for sent in sentence_list:
    for word, frequency in word_frequencies.items():
        if word in sent.lower():
            if sent not in sentence_scores.keys():
                sentence_scores[sent] = frequency
            else:
                sentence_scores[sent] += frequency

# %%
sentence_scores
# Out:
# {' Python is a high-level, general-purpose programming language.': 1.5535714285714284,
#  'Its design philosophy emphasizes code readability with the use of significant indentation.': 0.6785714285714284,
#  'Python is dynamically typed and garbage-collected.': 1.5238095238095233,
#  'It supports multiple programming paradigms, including structured (particularly procedural), object-oriented and functional programming.': 1.0238095238095235,
#  'It is often described as a "batteries included" language due to its comprehensive standard library.': 0.869047619047619,
#  'Guido van Rossum began working on Python in the late 1980s as a successor to the ABC programming language and first released it in 1991 as Python 0.9.0.': 2.0238095238095233,
#  'Python 2.0 was released in 2000.': 1.1607142857142856,
#  'Python 3.0, released in 2008, was a major revision not completely backward-compatible with earlier versions.': 1.5476190476190472,
#  'Python 2.7.18, released in 2020, was the last release of Python 2.': 1.1666666666666665,
#  'Python consistently ranks as one of the most popular programming languages, and has gained widespread use in the machine learning community.': 2.1071428571428568,
#  'Python was invented in the late 1980s by Guido van Rossum at Centrum Wiskunde & Informatica (CWI) in the Netherlands as a successor to the ABC programming language, which was inspired by SETL, capable of exception handling and interfacing with the Amoeba operating system.': 2.124999999999999,
#  'Its implementation began in December 1989.': 0.40476190476190477,
#  'Van Rossum shouldered sole responsibility for the project, as the lead developer, until 12 July 2018, when he announced his "permanent vacation" from his responsibilities as Python\'s "benevolent dictator for life" (BDFL), a title the Python community bestowed upon him to reflect his long-term commitment as the project\'s chief decision-maker (he\'s since come out of retirement and is self-titled "BDFL-emeritus").': 1.869047619047618,
#  'In January 2019, active Python core developers elected a five-member Steering Council to lead the project.': 1.535714285714285,
#  'Python 2.0 was released on 16 October 2000, with many major new features such as list comprehensions, cycle-detecting garbage collection, reference counting, and Unicode support.': 2.077380952380952,
#  'Python 3.0, released on 3 December 2008, with many of its major features backported to Python 2.6.x and 2.7.x.': 1.6547619047619042,
#  'Releases of Python 3 include the 2to3 utility, which automates the translation of Python 2 code to Python 3.': 1.452380952380952,
#  "Python 2.7's end-of-life was initially set for 2015, then postponed to 2020 out of concern that a large body of existing code could not easily be forward-ported to Python 3.": 1.7023809523809519,
#  'No further security patches or other improvements will be released for it.': 0.47023809523809523,
#  'Currently only 3.8 and later are supported (2023 security issues were fixed in e.g.': 0.5952380952380952,
#  '3.7.17, the final 3.7.x release ).': 0.12499999999999999,
#  'While Python 2.7 and older is officially unsupported, a different unofficial Python implementation, PyPy, continues to support Python 2, i.e.': 1.5178571428571426,
#  '"2.7.18+" (plus 3.9 and 3.10), with the plus meaning (at least some) "backported security updates".': 0.5297619047619047,
#  'In 2021 (and again twice in 2022), security updates were expedited, since all Python versions were insecure (including 2.7 ) because of security issues leading to possible remote code execution and web-cache poisoning.': 2.130952380952381,
#  'In 2022, Python 3.10.4 and 3.9.12 were expedited and 3.8.13, because of many security issues.': 1.6666666666666665,
#  'When Python 3.9.13 was released in May 2022, it was announced that the 3.9 series (joining the older series 3.8 and 3.7) would only receive security fixes in the future.': 1.6011904761904756,
#  'On 7 September 2022, four new releases were made due to a potential denial-of-service attack: 3.10.7, 3.9.14, 3.8.14, and 3.7.14.': 0.5059523809523808,
#  'As of October 2023,[update] Python 3.12 is the stable release, and 3.12 and 3.11 are the only versions with active (as opposed to just security) support.': 1.6726190476190474,
#  'Notable changes in 3.11 from 3.10 include increased program execution speed and improved error reporting.': 0.6011904761904762,
#  'Python 3.12 adds syntax (and in fact every Python since at least 3.5 adds some syntax) to the language, the new (soft) keyword type (recent releases have added a lot of typing support e.g.': 2.041666666666666,
#  'new type union operator in 3.10), and 3.11 for exception handling, and 3.10 the match and case (soft) keywords, for structural pattern matching statements.': 0.6369047619047619,
#  'Python 3.12 also drops outdated modules and functionality, and future versions will too, see below in Development section.': 1.7857142857142854,
#  'Python 3.11 claims to be between 10 and 60% faster than Python 3.10, and Python 3.12 adds another 5% on top of that.': 1.3928571428571423,
#  'It also has improved error messages, and many other changes.': 0.5297619047619047,
#  "Since 27 June 2023[update], Python 3.8 is the oldest supported version of Python (albeit in the 'security support' phase), due to Python 3.7 reaching end-of-life.": 1.8095238095238093,
#  'Python 3.13 introduced an incremental (shorter pauses for collection in programs with a lot of objects) garbage collector, an experimental JIT compiler, and removals from the C API.': 1.8749999999999993,
#  'Some standard library modules, 19 dead batteries, and many deprecated classes, functions and methods, and more will be removed in Python 3.15 and or 3.16.': 1.928571428571428,
#  'Starting with 3.13, it and later versions have 2 years of full support (up from one and a half); followed by 3 years of security support (for same total support as before).': 0.7499999999999997,
#  'Python is a multi-paradigm programming language.': 1.5178571428571428,
#  'Object-oriented programming and structured programming are fully supported, and many of their features support functional programming and aspect-oriented programming (including metaprogramming and metaobjects).': 1.1607142857142851,
#  'Many other paradigms are supported via extensions, including design by contract and logic programming.': 1.0178571428571428,
#  'Python uses dynamic typing and a combination of reference counting and a cycle-detecting garbage collector for memory management.': 1.7499999999999996,
#  'It uses dynamic name resolution (late binding), which binds method and variable names during program execution.': 0.7916666666666665,
#  'Its design offers some support for functional programming in the Lisp tradition.': 0.6428571428571428,
#  'It has filter,mapandreduce functions; list comprehensions, dictionaries, sets, and generator expressions.': 0.5119047619047618,
#  'The standard library has two modules (itertools and functools) that implement functional tools borrowed from Haskell and Standard ML.': 0.6666666666666666,
#  'Its core philosophy is summarized in the Zen of Python (PEP 20), which includes aphorisms such as: However, Python features regularly violate these principles and received criticism for adding unnecessary language bloat.': 1.9404761904761896,
#  'Responses to these criticisms are that the Zen of Python is a guideline rather than a rule.': 1.3809523809523805,
#  'The addition of some new features had been so controversial that Guido van Rossum resigned as Benevolent Dictator for Life following vitriol over the addition of the assignment expression operator in Python 3.8.': 1.797619047619047,
#  'Nevertheless, rather than building all of its functionality into its core, Python was designed to be highly extensible via modules.': 1.7321428571428563,
#  'This compact modularity has made it particularly popular as a means of adding programmable interfaces to existing applications.': 0.6964285714285713,
#  "Van Rossum's vision of a small core language with a large standard library and easily extensible interpreter stemmed from his frustrations with ABC, which espoused the opposite approach.": 1.2321428571428568,
#  'Python claims to strive for a simpler, less-cluttered syntax and grammar while giving developers a choice in their coding methodology.': 1.535714285714285,
#  'In contrast to Perl\'s "there is more than one way to do it" motto, Python embraces a "there should be one—and preferably only one—obvious way to do it."': 1.44047619047619,
#  'philosophy.': 0.03571428571428571,
#  'In practice, however, Python provides many ways to achieve the same task.': 1.488095238095238,
#  'There are, for example, at least three ways to format a string literal, with no certainty as to which one a programmer should use.': 0.6607142857142856,
#  'Alex Martelli, a Fellow at the Python Software Foundation and Python book author, wrote: "To describe something as \'clever\' is not considered a compliment in the Python culture."': 1.5535714285714277,
#  "Python's developers usually strive to avoid premature optimization and reject patches to non-critical parts of the CPython reference implementation that would offer marginal increases in speed at the cost of clarity.": 1.7202380952380945,
#  'Execution speed can be improved by moving speed-critical functions to extension modules written in languages such as C, or by using a just-in-time compiler like PyPy.': 1.166666666666666,
#  "It is also possible to cross-compile to other languages, but it either doesn't provide the full speed-up that might be expected, since Python is a very dynamic language, or a restricted subset of Python is compiled, and possibly semantics are slightly changed.": 2.142857142857142,
#  "Python's developers aim for it to be fun to use.": 1.333333333333333,
#  'This is reflected in its name—a tribute to the British comedy group Monty Python —and in occasionally playful approaches to tutorials and reference materials, such as the use of the terms "spam" and "eggs" (a reference to a Monty Python sketch) in examples, instead of the often-used "foo" and "bar".': 2.0297619047619038,
#  'A common neologism in the Python community is pythonic, which has a wide range of meanings related to program style.': 1.5238095238095233,
#  '"Pythonic" code may use Python idioms well, be natural or show fluency in the language, or conform with Python\'s minimalist philosophy and emphasis on readability.': 1.9464285714285707,
#  'Code that is difficult to understand or reads like a rough transcription from another programming language is called unpythonic.': 1.928571428571428,
#  'Python is meant to be an easily readable language.': 1.4404761904761902,
#  'Its formatting is visually uncluttered and often uses English keywords where other languages use punctuation.': 0.8928571428571427,
#  'Unlike many other languages, it does not use curly brackets to delimit blocks, and semicolons after statements are allowed but rarely used.': 1.2202380952380947,
#  'It has fewer syntactic exceptions and special cases than C or Pascal.': 0.2916666666666666,
#  'Python uses whitespace indentation, rather than curly brackets or keywords, to delimit blocks.': 1.6369047619047614,
#  'An increase in indentation comes after certain statements; a decrease in indentation signifies the end of the current block.': 0.5476190476190474,
#  "Thus, the program's visual structure accurately represents its semantic structure.": 0.3749999999999999,
#  'This feature is sometimes termed the off-side rule.': 0.1845238095238095,
#  'Some other languages use indentation this way; but in most, indentation has no semantic meaning.': 0.8333333333333334,
#  'The recommended indent size is four spaces.': 0.25595238095238093,
#  "Python's statements include: The assignment statement (=) binds a name as a reference to a separate, dynamically allocated object.": 1.7321428571428565,
#  'Variables may subsequently be rebound at any time to any object.': 0.4583333333333333,
#  'In Python, a variable name is a generic reference holder without a fixed data type; however, it always refers to some object with a type.': 1.803571428571428,
#  'This is called dynamic typing—in contrast to statically-typed languages, where each variable may contain only a value of a certain type.': 0.9761904761904759,
#  'Python does not support tail call optimization or first-class continuations, and, according to Van Rossum, it never will.': 1.5714285714285714,
#  "However, better support for coroutine-like functionality is provided by extending Python's generators.": 1.8214285714285707,
#  'Before 2.5, generators were lazy iterators; data was passed unidirectionally out of the generator.': 0.4702380952380951,
#  'From Python 2.5 on, it is possible to pass data back into a generator function; and from version 3.3, it can be passed through multiple stack levels.': 1.5833333333333328,
#  "Python's expressions include: In Python, a distinction between expressions and statements is rigidly enforced, in contrast to languages such as Common Lisp, Scheme, or Ruby.": 1.9880952380952377,
#  'This leads to duplicating some functionality.': 0.36309523809523797,
#  'For example: Statements cannot be a part of an expression—so list and other comprehensions or lambda expressions, all being expressions, cannot contain statements.': 0.6726190476190474,
#  'A particular case is that an assignment statement such as a = 1 cannot form part of the conditional expression of a conditional statement.': 0.44642857142857134,
#  "Methods on objects are functions attached to the object's class; the syntax instance.method(argument) is, for normal methods and functions, syntactic sugar for Class.method(instance, argument).": 0.7261904761904762,
#  'Python methods have an explicit self parameter to access instance data, in contrast to the implicit self (or this) in some other object-oriented programming languages (e.g., C++, Java, Objective-C, Ruby).': 2.208333333333333,
#  'Python also provides methods, often called dunder methods (due to their names beginning and ending with double-underscores), to allow user-defined classes to modify how they are handled by native operations including length, comparison, in arithmetic operations and type conversion.': 2.4047619047619038,
#  'Python uses duck typing and has typed objects but untyped variable names.': 1.8273809523809519,
#  'Type constraints are not checked at compile time; rather, operations on an object may fail, signifying that it is not of a suitable type.': 0.6666666666666664,
#  'Despite being dynamically typed, Python is strongly typed, forbidding operations that are not well-defined (for example, adding a number to a string) rather than silently attempting to make sense of them.': 1.8035714285714273,
#  'Python allows programmers to define their own types using classes, most often used for object-oriented programming.': 2.154761904761905,
#  'New instances of classes are constructed by calling the class (for example, SpamClass() or EggsClass()), and the classes are instances of the metaclass type (itself an instance of itself), allowing metaprogramming and reflection.': 0.9702380952380948,
#  'Before version 3.0, Python had two kinds of classes (both using the same syntax): old-style and new-style; current Python versions only support the semantics of the new style.': 1.8928571428571428,
#  'Python supports optional type annotations.': 1.3035714285714284,
#  'These annotations are not enforced by the language, but may be used by external tools such as mypy to catch errors.': 0.9226190476190474,
#  'Mypy also supports a Python compiler called mypyc, which leverages type annotations for optimization.': 1.7023809523809519,
#  '1.33333 Python has the usual symbols for arithmetic operators (+, -, *, /), the floor division operator // and the modulo operation % (where the remainder can be negative, e.g.': 1.5654761904761898,
#  'It also has ** for exponentiation, e.g.': 0.30357142857142855,
#  '5**3 == 125 and 9**0.5 == 3.0, and a matrix‑multiplication operator @ .': 0.2738095238095237,
#  'These operators work like in traditional math; with the same precedence rules, the operators infix (+ and - can also be unary to represent positive and negative numbers respectively).': 0.7976190476190473,
#  'The division between integers produces floating-point results.': 0.49404761904761896,
#  'The behavior of division has changed significantly over time: In Python terms, / is true division (or simply division), and // is floor division.': 1.5119047619047614,
#  '/ before version 3.0 is classic division.': 0.4166666666666667,
#  'Rounding towards negative infinity, though different from most languages, adds consistency.': 0.720238095238095,
#  'For instance, it means that the equation (a + b)//b == a//b + 1 is always true.': 0.42261904761904756,
#  'It also means that the equation b*(a//b) + a%b == a is valid for both positive and negative values of a.': 0.43452380952380937,
#  'However, maintaining the validity of this equation means that while the result of a%b is, as expected, in the half-open interval [0, b), where b is a positive integer, it has to lie in the interval (b, 0] when b is negative.': 0.6249999999999996,
#  'Python provides a round function for rounding a float to the nearest integer.': 1.452380952380952,
#  'For tie-breaking, Python 3 uses round to even: round(1.5) and round(2.5) both produce 2.': 1.5892857142857142,
#  'Versions before 3 used round-away-from-zero: round(0.5) is 1.0, round(-0.5) is −1.0.': 0.5357142857142856,
#  'Python allows Boolean expressions with multiple equality relations in a manner that is consistent with general use in mathematics.': 1.7023809523809519,
#  'For example, the expression a < b < c tests whether a is less than b and b is less than c. C-derived languages interpret this expression differently: in C, the expression would first evaluate a < b, resulting in 0 or 1, and that result would then be compared with c. Python uses arbitrary-precision arithmetic for all integer operations.': 2.2559523809523796,
#  'The Decimal type/class in the decimal module provides decimal floating-point numbers to a pre-defined arbitrary precision and several rounding modes.': 0.8035714285714285,
#  'The Fraction class in the fractions module provides arbitrary precision for rational numbers.': 0.5416666666666665,
#  "Due to Python's extensive mathematics library, and the third-party library NumPy that further extends the native capabilities, it is frequently used as a scientific scripting language to aid in problems such as numerical data processing and manipulation.": 2.2738095238095224,
#  '"Hello, World!"': 0.07738095238095238,
#  "program: Program to calculate the factorial of a positive integer: Python's large standard library provides tools suited to many tasks and is commonly cited as one of its greatest strengths.": 2.029761904761904,
#  'For Internet-facing applications, many standard formats and protocols such as MIME and HTTP are supported.': 0.726190476190476,
#  'It includes modules for creating graphical user interfaces, connecting to relational databases, generating pseudorandom numbers, arithmetic with arbitrary-precision decimals, manipulating regular expressions, and unit testing.': 1.0595238095238093,
#  'Some parts of the standard library are covered by specifications—for example, the Web Server Gateway Interface (WSGI) implementation wsgiref follows PEP 333 —but most are specified by their code, internal documentation, and test suites.': 1.0535714285714284,
#  'However, because most of the standard library is cross-platform Python code, only a few modules need altering or rewriting for variant implementations.': 1.9464285714285712,
#  'As of 17 March 2024,[update] the Python Package Index (PyPI), the official repository for third-party Python software, contains over 523,000 packages with a wide range of functionality, including: Most Python implementations (including CPython) include a read–eval–print loop (REPL), permitting them to function as a command line interpreter for which users enter statements sequentially and receive results immediately.': 2.309523809523808,
#  'Python also comes with an Integrated development environment (IDE) called IDLE, which is more beginner-oriented.': 1.696428571428571,
#  'Other shells, including IDLE and IPython, add further abilities such as improved auto-completion, session state retention, and syntax highlighting.': 1.648809523809523,
#  'As well as standard desktop integrated development environments including PyCharm, IntelliJ Idea, Visual Studio Code etc, there are web browser-based IDEs, including SageMath, for developing science- and math-related programs; PythonAnywhere, a browser-based IDE and hosting environment; and Canopy IDE, a commercial IDE emphasizing scientific computing.': 2.1666666666666656,
#  'CPython is the reference implementation of Python.': 1.3511904761904763,
#  'It is written in C, meeting the C89 standard (Python 3.11 uses C11 ) with several select C99 features.': 1.6607142857142856,
#  'CPython includes its own C extensions, but third-party extensions are not limited to older C versions—e.g.': 1.7321428571428568,
#  'they can be implemented with C11 or C++.': 0.30357142857142855,
#  'CPython compiles Python programs into an intermediate bytecode which is then executed by its virtual machine.': 1.6785714285714284,
#  'CPython is distributed with a large standard library written in a mixture of C and native Python, and is available for many platforms, including Windows (starting with Python 3.9, the Python installer deliberately fails to install on Windows 7 and 8; Windows XP was supported until Python 3.5) and most modern Unix-like systems, including macOS (and Apple M1 Macs, since Python 3.9.1, with experimental installer), with unofficial support for VMS.': 2.4821428571428563,
#  'Platform portability was one of its earliest priorities.': 0.25595238095238093,
#  '(During Python 1 and 2 development, even OS/2 and Solaris were supported, but support has since been dropped for many platforms.)': 1.833333333333333,
#  'Python, since 3.7, only supports operating systems with multi-threading support.': 1.5476190476190472,
#  "Other just-in-time Python compilers have been developed, but are now unsupported: There are several compilers/transpilers to high-level object languages, with either unrestricted Python, a restricted subset of Python, or a language similar to Python as the source language: Specialized: Older projects (or not to be used with Python 3.x and latest syntax): Performance comparison of various Python implementations on a non-numerical (combinatorial) workload was presented at EuroSciPy '13.": 2.7202380952380936,
#  "Python's performance compared to other programming languages is also benchmarked by The Computer Language Benchmarks Game.": 2.017857142857143,
#  "Python's development is conducted largely through the Python Enhancement Proposal (PEP) process, the primary mechanism for proposing major new features, collecting community input on issues, and documenting Python design decisions.": 1.7976190476190472,
#  'Python coding style is covered in PEP 8.': 1.339285714285714,
#  'Outstanding PEPs are reviewed and commented on by the Python community and the steering council.': 1.4761904761904758,
#  'Enhancement of the language corresponds with the development of the CPython reference implementation.': 1.7083333333333333,
#  "The mailing list python-dev is the primary forum for the language's development.": 1.452380952380952,
#  'Specific issues were originally discussed in the Roundup bug tracker hosted at by the foundation.': 0.5059523809523809,
#  'In 2022, all issues and discussions were migrated to GitHub.': 0.4047619047619047,
#  'Development originally took place on a self-hosted source-code repository running Mercurial, until Python moved to GitHub in January 2017.': 1.666666666666666,
#  "CPython's public releases come in three types, distinguished by which part of the version number is incremented: Many alpha, beta, and release-candidates are also released as previews and for testing before final releases.": 2.0238095238095233,
#  'Although there is a rough schedule for each release, they are often delayed if the code is not ready.': 0.47023809523809507,
#  "Python's development team monitors the state of the code by running the large unit test suite during development.": 1.6249999999999998,
#  'The major academic conference on Python is PyCon.': 1.2499999999999998,
#  'There are also special Python mentoring programs, such as PyLadies.': 1.4702380952380953,
#  'Python 3.12 removed wstr meaning Python extensions need to be modified, and 3.10 added pattern matching to the language.': 1.7261904761904754,
#  "Python 3.12 dropped some outdated modules, and more will be dropped in the future, deprecated as of 3.13; already deprecated array 'u' format code will emit DeprecationWarning since 3.13 and will be removed in Python 3.16.": 1.773809523809523,
#  "The 'w' format code should be used instead.": 0.6488095238095237,
#  'Part of ctypes is also deprecated and http.server.CGIHTTPRequestHandler will emit a DeprecationWarning, and will be removed in 3.15.': 0.7023809523809521,
#  'Using that code already has a high potential for both security and functionality bugs.': 0.7083333333333331,
#  'Parts of the typing module are deprecated, e.g.': 0.40476190476190466,
#  'creating a typing.NamedTuple class using keyword arguments to denote the fields and such (and more) will be disallowed in Python 3.15.': 1.6011904761904758,
#  'Tools that can generate documentation for Python API include pydoc (available as part of the standard library), Sphinx, Pdoc and its forks, Doxygen and Graphviz, among others.': 1.785714285714285,
#  "Python's name is derived from the British comedy group Monty Python, whom Python creator Guido van Rossum enjoyed while developing the language.": 1.8214285714285707,
#  'Monty Python references appear frequently in Python code and culture; for example, the metasyntactic variables often used in Python literature are spam and eggs instead of the traditional foo and bar.': 2.06547619047619,
#  'The official Python documentation also contains various references to Monty Python routines.': 1.4940476190476186,
#  'Users of Python are sometimes referred to as "Pythonistas".': 1.2738095238095235,
#  'The prefix Py- is used to show that something is related to Python.': 1.464285714285714,
#  'Examples of the use of this prefix in names of Python applications or libraries include Pygame, a binding of SDL to Python (commonly used to create games); PyQt and PyGTK, which bind Qt and GTK to Python respectively; and PyPy, a Python implementation originally written in Python.': 2.13095238095238,
#  'Since 2003, Python has consistently ranked in the top ten most popular programming languages in the TIOBE Programming Community Index where as of December 2022[update] it was the most popular language (ahead of C, C++, and Java).': 2.1428571428571423,
#  'It was selected as Programming Language of the Year (for "the highest rise in ratings in a year") in 2007, 2010, 2018, and 2020 (the only language to have done so four times as of 2020[update] ).': 0.839285714285714,
#  'Large organizations that use Python include Wikipedia, Google, Yahoo!, CERN, NASA, Facebook, Amazon, Instagram, Spotify, and some smaller entities like ILM and ITA.': 1.7440476190476186,
#  'The social news networking site Reddit was written mostly in Python.': 1.4404761904761902,
#  'Python can serve as a scripting language for web applications, e.g.': 1.6845238095238093,
#  'via mod_wsgi for the Apache webserver.': 0.4523809523809523,
#  'With Web Server Gateway Interface, a standard API has evolved to facilitate these applications.': 0.6488095238095236,
#  'Web frameworks like Django, Pylons, Pyramid, TurboGears, web2py, Tornado, Flask, Bottle, and Zope support developers in the design and maintenance of complex applications.': 0.8630952380952376,
#  'Pyjs and IronPython can be used to develop the client-side of Ajax-based applications.': 1.696428571428571,
#  'SQLAlchemy can be used as a data mapper to a relational database.': 0.595238095238095,
#  'Twisted is a framework to program communications between computers, and is used (for example) by Dropbox.': 0.7440476190476188,
#  'Libraries such as NumPy, SciPy and Matplotlib allow the effective use of Python in scientific computing, with specialized libraries such as Biopython and Astropy providing domain-specific functionality.': 1.7321428571428563,
#  'SageMath is a computer algebra system with a notebook interface programmable in Python: its library covers many aspects of mathematics, including algebra, combinatorics, numerical mathematics, number theory, and calculus.': 1.9047619047619038,
#  'OpenCV has Python bindings with a rich set of features for computer vision and image processing.': 1.5595238095238089,
#  'Python is commonly used in artificial intelligence projects and machine learning projects with the help of libraries like TensorFlow, Keras, Pytorch, scikit-learn and the Logic language ProbLog.': 2.0535714285714275,
#  'As a scripting language with a modular architecture, simple syntax, and rich text processing tools, Python is often used for natural language processing.': 1.9821428571428563,
#  'The combination of Python and Prolog has proved to be particularly useful for AI applications, with Prolog providing knowledge representation and reasoning capablities.': 1.684523809523809,
#  'The Janus system, in particular, exploits the similarites between these two languages, in part because of their use of dynamic typing, and the simple recursive nature of their data structures.': 1.06547619047619,
#  'Typical applications of this combination include natural language processing, visual query answering, geospatial reasoning, and handling of semantic web data.': 0.9285714285714286,
#  'The Natlog system, implemented in Python, uses Definite Clause Grammars (DCGs) as prompt generators for text-to-text generators like GPT3 and text-to-image generators like DALL-E or Stable Diffusion.': 1.8333333333333324,
#  'Python can also be used for graphical user interface (GUI) by using libraries like Tkinter.': 1.8988095238095235,
#  'Python has been successfully embedded in many software products as a scripting language, including in finite element method software such as Abaqus, 3D parametric modelers like FreeCAD, 3D animation packages such as 3ds Max, Blender, Cinema 4D, Lightwave, Houdini, Maya, modo, MotionBuilder, Softimage, the visual effects compositor Nuke, 2D imaging programs like GIMP, Inkscape, Scribus and Paint Shop Pro, and musical notation programs like scorewriter and capella.': 2.416666666666665,
#  'GNU Debugger uses Python as a pretty printer to show complex structures such as C++ containers.': 1.6607142857142851,
#  'Esri promotes Python as the best choice for writing scripts in ArcGIS.': 1.3988095238095235,
#  'It has also been used in several video games, and has been adopted as first of the three available programming languages in Google App Engine, the other two being Java and Go.': 1.2440476190476184,
#  'Many operating systems include Python as a standard component.': 1.6488095238095235,
#  'It ships with most Linux distributions, AmigaOS 4 (using Python 2.7), FreeBSD (as a package), NetBSD, and OpenBSD (as a package) and can be used from the command line (terminal).': 1.7797619047619042,
#  'Many Linux distributions use installers written in Python: Ubuntu uses the Ubiquity installer, while Red Hat Linux and Fedora Linux use the Anaconda installer.': 1.7678571428571423,
#  'Gentoo Linux uses Python in its package management system, Portage.': 1.5535714285714282,
#  'Python is used extensively in the information security industry, including in exploit development.': 1.809523809523809,
#  'Most of the Sugar software for the One Laptop per Child XO, developed at Sugar Labs as of 2008[update], is written in Python.': 1.6428571428571423,
#  'The Raspberry Pi single-board computer project has adopted Python as its main user-programming language.': 1.9345238095238089,
#  'LibreOffice includes Python and intends to replace Java with Python.': 1.4702380952380947,
#  'Its Python Scripting Provider is a core feature since Version 4.0 from 7 February 2013.': 1.56547619047619,
#  "Python's design and philosophy have influenced many other programming languages: Python's development practices have also been emulated by other languages.": 2.25,
#  'For example, the practice of requiring a document describing the rationale for, and issues surrounding, a change to the language (in Python, a PEP) is also used in Tcl, Erlang, and Swift.': 2.1488095238095233}

# %%
avg_score = sum([sentence_scores[sent] for sent in sentence_scores]) / len(sentence_scores)

# %%
avg_score
# Out:
# 1.3385819845179445

# %%
summary = []
for sent in sentence_list:
    if (sent in sentence_scores) and (sentence_scores[sent] > (1.5 * avg_score)):
        summary.append(sent)

# %%
final = " ".join(summary)

# %%
final
# Out:
# 'Guido van Rossum began working on Python in the late 1980s as a successor to the ABC programming language and first released it in 1991 as Python 0.9.0. Python consistently ranks as one of the most popular programming languages, and has gained widespread use in the machine learning community. Python was invented in the late 1980s by Guido van Rossum at Centrum Wiskunde & Informatica (CWI) in the Netherlands as a successor to the ABC programming language, which was inspired by SETL, capable of exception handling and interfacing with the Amoeba operating system. Python 2.0 was released on 16 October 2000, with many major new features such as list comprehensions, cycle-detecting garbage collection, reference counting, and Unicode support. In 2021 (and again twice in 2022), security updates were expedited, since all Python versions were insecure (including 2.7 ) because of security issues leading to possible remote code execution and web-cache poisoning. Python 3.12 adds syntax (and in fact every Python since at least 3.5 adds some syntax) to the language, the new (soft) keyword type (recent releases have added a lot of typing support e.g. It is also possible to cross-compile to other languages, but it either doesn\'t provide the full speed-up that might be expected, since Python is a very dynamic language, or a restricted subset of Python is compiled, and possibly semantics are slightly changed. This is reflected in its name—a tribute to the British comedy group Monty Python —and in occasionally playful approaches to tutorials and reference materials, such as the use of the terms "spam" and "eggs" (a reference to a Monty Python sketch) in examples, instead of the often-used "foo" and "bar". Python methods have an explicit self parameter to access instance data, in contrast to the implicit self (or this) in some other object-oriented programming languages (e.g., C++, Java, Objective-C, Ruby). Python also provides methods, often called dunder methods (due to their names beginning and ending with double-underscores), to allow user-defined classes to modify how they are handled by native operations including length, comparison, in arithmetic operations and type conversion. Python allows programmers to define their own types using classes, most often used for object-oriented programming. For example, the expression a < b < c tests whether a is less than b and b is less than c. C-derived languages interpret this expression differently: in C, the expression would first evaluate a < b, resulting in 0 or 1, and that result would then be compared with c. Python uses arbitrary-precision arithmetic for all integer operations. Due to Python\'s extensive mathematics library, and the third-party library NumPy that further extends the native capabilities, it is frequently used as a scientific scripting language to aid in problems such as numerical data processing and manipulation. program: Program to calculate the factorial of a positive integer: Python\'s large standard library provides tools suited to many tasks and is commonly cited as one of its greatest strengths. As of 17 March 2024,[update] the Python Package Index (PyPI), the official repository for third-party Python software, contains over 523,000 packages with a wide range of functionality, including: Most Python implementations (including CPython) include a read–eval–print loop (REPL), permitting them to function as a command line interpreter for which users enter statements sequentially and receive results immediately. As well as standard desktop integrated development environments including PyCharm, IntelliJ Idea, Visual Studio Code etc, there are web browser-based IDEs, including SageMath, for developing science- and math-related programs; PythonAnywhere, a browser-based IDE and hosting environment; and Canopy IDE, a commercial IDE emphasizing scientific computing. CPython is distributed with a large standard library written in a mixture of C and native Python, and is available f ...

# %%
len(final)
# Out:
# 6883

# %%
len(formatted_article_content)
# Out:
# 26151
